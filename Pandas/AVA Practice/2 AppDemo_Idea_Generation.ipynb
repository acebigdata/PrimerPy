# %% [markdown]
# # 1. Idea Generation

# %%
import numpy as np
import pandas as pd
import sqlite3
import sys
import sqlalchemy
from ipywidgets import *
import ipywidgets as widgets
from IPython.display import display
from traitlets import link

# %% [markdown]
# ## 1.1 Data Prep

# %%
#Loading database after selection
## Connecting database
db_conn = sqlite3.connect('AVA_FY.db')
db_cur = db_conn.cursor()

# %%
#load all tables
db_cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
metric_tables = db_cur.fetchall()
metric_names = [i[0] for i in metric_tables]
var_names = [name.replace(" ", "_") for name in metric_names]
df_ava = {}
for i in range(len(var_names)):
    sql_query = 'SELECT * FROM "{table_name}"'.format(table_name=metric_names[i])
    key = metric_names[i]
    value = pd.read_sql(sql_query, db_conn)
    df_ava[key] = value

# %%
criteria_table = {"Falling Revenue":"Total Revenue", 
                  "Rising COGS%":"COGS Ratio", 
                  "Falling Gross Profit Margin":"Gross Profit Margin", 
                  "Rising SG&A%":"SG&A Ratio",
                  "Falling EBT Margin":"EBT Margin", 
                  "Falling EBIT Margin":"EBIT Margin", 
                  "Falling EBITDA Margin":"EBITDA Margin", 
                  "Falling NOPAT Margin":"NOPAT Margin",
                  "Falling Inventory Turnover": "Inventory Turnover", 
                  "Falling Fixed Asset Turnover": "Fixed Asset Turnover", 
                  "Rising DSO":"DSO", 
                  "Falling DPO":"DPO", 
                 }
column_names = list(df_ava["Total Revenue"].columns)

# %% [markdown]
# ## 1.2 Select Metrics, Criteria and Years to Generate Idea/Target Lists

# %%
falling_list = ["Falling Revenue", "Falling Gross Profit Margin","Falling EBT Margin", "Falling EBIT Margin", "Falling EBITDA Margin", "Falling NOPAT Margin",
                 "Falling Inventory Turnover", "Falling Fixed Asset Turnover", "Falling DSO",]
rising_list = ["Rising COGS%", "Rising SG&A%", "Rising DPO",]
year_list = column_names[column_names.index("FY1998"):]
select_ideas = widgets.Accordion(
    children=[widgets.SelectMultiple(description="Select Falling Metrics",options=falling_list),
              widgets.SelectMultiple(description="Select Rising Metrics",options=rising_list),
              widgets.SelectMultiple(description="Select Years To Be Included",options=year_list),
              widgets.FloatSlider(
                    value=0,
                    min=0,
                    max=2.0,
                    step=0.01,
                    description='Criteria:',
                    disabled=False,
                    continuous_update=False,
                    orientation='horizontal',
                    readout=True,
                    readout_format='.0%',
                    slider_color='#CB1B45'
                ),
             ])
select_ideas.set_title(0, 'Falling Metrics')
select_ideas.set_title(1, 'Rising Metrics')
select_ideas.set_title(2, 'Years')
select_ideas.set_title(3, 'Criteria (Inclusive WIP)')
select_ideas

# %%
column_names = list(df_ava["Total Revenue"].columns)

falling_list = list(select_ideas.children[0].value)
rising_list = list(select_ideas.children[1].value)
change_criteria = select_ideas.children[3].value

# %%
year_list = list(select_ideas.children[2].value)
inspection_years = year_list
year_len = len(inspection_years)
first_inspect_year_index = column_names.index(inspection_years[0])
inspection_year_previous = column_names[first_inspect_year_index-1:first_inspect_year_index+year_len-1]

# %%
## Define columns to display
info_list=["Company Name", "Exchange:Ticker", "Country", "Region", "AV Industry", "AV Sector"]
display_columns = info_list + inspection_years

## Falling metrics generation
temp_db = {}
temp_df = df_ava["Total Revenue"]
#Falling metrics
for idea in falling_list:
    table_name = criteria_table[idea]
    key=idea
    temp_df = df_ava[table_name]
    for i,j in zip(inspection_years, inspection_year_previous):
        temp_df = temp_df[temp_df.loc[ : , i] < temp_df.loc[ : , j]]
#         temp_df = temp_df[((temp_df.loc[:,i] - temp_df.loc[:,j]) / temp_df.loc[:,j]) < change_criteria]
    temp_db[key] = temp_df.loc[:,display_columns]

#Rising metrices
for idea in rising_list:
    table_name = criteria_table[idea]
    key=idea
    temp_df = df_ava[table_name]
    for i,j in zip(inspection_years, inspection_year_previous):
        temp_df = temp_df[temp_df.loc[ : , i] > temp_df.loc[ : , j]]
    temp_db[key] = temp_df.loc[:,display_columns]

# %%
temp_db.keys()
# Out:
# dict_keys(['Falling Revenue', 'Falling EBIT Margin', 'Falling NOPAT Margin', 'Rising COGS%', 'Rising SG&A%'])

# %%
for key in list(temp_db.keys()):
    print(temp_db[key].head())
# Out:
#                                   Company Name Exchange:Ticker        Country  \
# 3          Royal Dutch Shell plc (ENXTAM:RDSA)     ENXTAM:RDSA    Netherlands
# 6           Exxon Mobil Corporation (NYSE:XOM)        NYSE:XOM  United States
# 37              Chevron Corporation (NYSE:CVX)        NYSE:CVX  United States
# 92   Archer-Daniels-Midland Company (NYSE:ADM)        NYSE:ADM  United States
# 103                  ArcelorMittal (ENXTAM:MT)       ENXTAM:MT     Luxembourg
#
#             Region                 AV Industry  AV Sector  FY2013  FY2014  \
# 3           Europe  Resources/Process Material  Oil & Gas  451235  421105
# 6    North America  Resources/Process Material  Oil & Gas  390247  364763
# 37   North America  Resources/Process Material  Oil & Gas  211665  192308
# 92   North America  Resources/Process Material       Food   89804   81201
# 103         Europe  Resources/Process Material      Steel   79440   79282
#
#      FY2015
# 3    264960
# 6    236810
# 37   122566
# 92    67702
# 103   63578
#                            Company Name Exchange:Ticker         Country  \
# 0      Wal-Mart Stores, Inc. (NYSE:WMT)        NYSE:WMT   United States
# 3   Royal Dutch Shell plc (ENXTAM:RDSA)     ENXTAM:RDSA     Netherlands
# 6    Exxon Mobil Corporation (NYSE:XOM)        NYSE:XOM   United States
# 7       McKesson Corporation (NYSE:MCK)        NYSE:MCK   United States
# 10                  BP p.l.c. (LSE:BP.)         LSE:BP.  United Kingdom
#
#            Region                 AV Industry    AV Sector    FY2013  \
# 0   North America                    Services       Retail  0.059257
# 3          Europe  Resources/Process Material    Oil & Gas  0.061540
# 6   North America  Resources/Process Material    Oil & Gas  0.103270
# 7   North America                    Services  Health Care  0.018554
# 10         Europe  Resources/Process Material    Oil & Gas  0.044841
#
#       FY2014    FY2015
# 0   0.056419  0.056411
# 3   0.054680 -0.008764
# 6   0.093436  0.054402
# 7   0.018327  0.017420
# 10  0.011820  0.006463
# Empty DataFrame
# Columns: [Company Name, Exchange:Ticker, Country, Region, AV Industry, AV Sector, FY2013, FY2014, FY2015]
# Index: []
#                                          Company Name Exchange:Ticker  \
# 23                                  E.ON SE (DB:EOAN)         DB:EOAN
# 25           Fiat Chrysler Automobiles N.V. (BIT:FCA)         BIT:FCA
# 27                 General Electric Company (NYSE:GE)         NYSE:GE
# 34  Nippon Telegraph and Telephone Corporation (TS...        TSE:9432
# 46              Assicurazioni Generali S.p.A. (BIT:G)           BIT:G
#
#            Country         Region            AV Industry  \
# 23         Germany         Europe               Services
# 25  United Kingdom         Europe  Auto & Transportation
# 27   United States  North America            Engineering
# 34           Japan   Asia-Pacific                   TIME
# 46           Italy         Europe               Services
#
#                      AV Sector    FY2013    FY2014    FY2015
# 23                   Utilities  0.880155  0.880752  0.892918
# 25                    Auto OEM  0.858943  0.864950  0.876937
# 27  Equipment Mech./Industrial  0.529396  0.547689  0.690947
# 34          Telecome Operators  0.427090  0.447608  0.476245
# 46                   Insurance  0.858821  0.885032  0.885362
#                           Company Name Exchange:Ticker         Country  \
# 6   Exxon Mobil Corporation (NYSE:XOM)        NYSE:XOM   United States
# 7      McKesson Corporation (NYSE:MCK)        NYSE:MCK   United States
# 10                 BP p.l.c. (LSE:BP.)         LSE:BP.  United Kingdom
# 13             Glencore Plc (LSE:GLEN)        LSE:GLEN     Switzerland
# 21    Amazon.com, Inc. (NasdaqGS:AMZN)   NasdaqGS:AMZN   United States
#
#            Region                 AV Industry      AV Sector    FY2013  \
# 6   North America  Resources/Process Material      Oil & Gas  0.036354
# 7   North America                    Services    Health Care  0.034282
# 10         Europe  Resources/Process Material      Oil & Gas  0.037618
# 13         Europe  Resources/Process Material         Mining  0.005183
# 21  North America                        TIME  Online Retail  0.172554
#
#       FY2014    FY2015
# 6   0.037479  0.052717
# 7   0.039372  0.044129
# 10  0.038502  0.055460
# 13  0.005899  0.007455
# 21  0.187104  0.190746

# %%
temp_db['Falling Revenue']
# Out:
#                                            Company Name Exchange:Ticker  \
# 3                   Royal Dutch Shell plc (ENXTAM:RDSA)     ENXTAM:RDSA
# 6                    Exxon Mobil Corporation (NYSE:XOM)        NYSE:XOM
# 37                       Chevron Corporation (NYSE:CVX)        NYSE:CVX
# 92            Archer-Daniels-Midland Company (NYSE:ADM)        NYSE:ADM
# 103                           ArcelorMittal (ENXTAM:MT)       ENXTAM:MT
# 113                              Pfizer Inc. (NYSE:PFE)        NYSE:PFE
# 121                          Telefónica, S.A. (BME:TEF)         BME:TEF
# 126       Hewlett Packard Enterprise Company (NYSE:HPE)        NYSE:HPE
# 136                                  HP Inc. (NYSE:HPQ)        NYSE:HPQ
# 142                                Statoil ASA (OB:STL)          OB:STL
# 143                        HSBC Holdings plc (LSE:HSBA)        LSE:HSBA
# 154         Compagnie de Saint-Gobain S.A. (ENXTPA:SGO)      ENXTPA:SGO
# 161                     The Coca-Cola Company (NYSE:KO)         NYSE:KO
# 177                         Caterpillar Inc. (NYSE:CAT)        NYSE:CAT
# 178                        Merck & Co., Inc. (NYSE:MRK)        NYSE:MRK
# 181                       Best Buy Co., Inc. (NYSE:BBY)        NYSE:BBY
# 185              Wilmar International Limited (SGX:F34)         SGX:F34
# 196              SK Innovation Co., Ltd. (KOSE:A096770)    KOSE:A096770
# 198   Hyundai Heavy Industries Co., Ltd. (KOSE:A009540)    KOSE:A009540
# 203                             Bouygues SA (ENXTPA:EN)       ENXTPA:EN
# 240                              Repsol, S.A. (BME:REP)         BME:REP
# 290          Philip Morris International Inc. (NYSE:PM)         NYSE:PM
# 319             Northrop Grumman Corporation (NYSE:NOC)        NYSE:NOC
# 324          Sears Holdings Corporation (NasdaqGS:SHLD)   NasdaqGS:SHLD
# 329                           ConocoPhillips (NYSE:COP)        NYSE:COP
# 343                       Aflac Incorporated (NYSE:AFL)        NYSE:AFL
# 360                   OMV Aktiengesellschaft (WBAG:OMV)        WBAG:OMV
# 361                     Telecom Italia S.p.A. (BIT:TIT)         BIT:TIT
# 368                       KT Corporation (KOSE:A030200)    KOSE:A030200
# 384                       Staples, Inc. (NasdaqGS:SPLS)   NasdaqGS:SPLS
# ...                                                 ...             ...
# 6318      Walter Investment Management Corp. (NYSE:WAC)        NYSE:WAC
# 6335                              Herige (ENXTPA:HERIG)    ENXTPA:HERIG
# 6357                    Hochschild Mining PLC (LSE:HOC)         LSE:HOC
# 6372           Lee Enterprises, Incorporated (NYSE:LEE)        NYSE:LEE
# 6401                              PMP Limited (ASX:PMP)         ASX:PMP
# 6464         Darfon Electronics Corporation (TSEC:8163)       TSEC:8163
# 6472                   Dubai Investments PJSC (DFM:DIC)         DFM:DIC
# 6476            Kesoram Industries Limited (BSE:502937)      BSE:502937
# 6504                            NEX Group plc (LSE:NXG)         LSE:NXG
# 6532                         Kisco Corp. (KOSE:A104700)    KOSE:A104700
# 6533                      Daisyo Corporation (TSE:9979)        TSE:9979
# 6550          V V Food & Beverage Co.,Ltd (SHSE:600300)     SHSE:600300
# 6566                      Mr. Bricolage SA (ENXTPA:MRB)      ENXTPA:MRB
# 6581  Shenzhen Yitoa Intelligent Control Co., Ltd. (...     SZSE:300131
# 6597                       Chemring Group plc (LSE:CHG)         LSE:CHG
# 6599                Southern Steel Berhad (KLSE:SSTEEL)     KLSE:SSTEEL
# 6606  Washington H. Soul Pattinson and Company Limit...         ASX:SOL
# 6635       Harbour Centre Development Limited (SEHK:51)         SEHK:51
# 6677              PT Delta Dunia Makmur Tbk (JKSE:DOID)       JKSE:DOID
# 6688  JiaoZuo WanFang Aluminum Manufacturing Co., Lt...     SZSE:000612
# 6740                           R1 RCM Inc. (OTCPK:ACHI)      OTCPK:ACHI
# 6768        China Steel Structure Co., Ltd. (TSEC:2013)       TSEC:2013
# 6837             Bridgepoint Education, Inc. (NYSE:BPI)        NYSE:BPI
# 6856              Avid Technology, Inc. (NasdaqGS:AVID)   NasdaqGS:AVID
# 6876                        Punch Taverns plc (LSE:PUB)         LSE:PUB
# 6941            Yokohama Maruuo Co., Ltd. (JASDAQ:8045)     JASDAQ:8045
# 6953              MK Electron Co. Ltd. (KOSDAQ:A033160)  KOSDAQ:A033160
# 7044                            Vocento, S.A. (BME:VOC)         BME:VOC
# 7092                Inter Parfums, Inc. (NasdaqGS:IPAR)   NasdaqGS:IPAR
# 7124             Mitsui Matsushima Co., Ltd. (TSE:1518)        TSE:1518
#
#                    Country         Region                 AV Industry  \
# 3              Netherlands         Europe  Resources/Process Material
# 6            United States  North America  Resources/Process Material
# 37           United States  North America  Resources/Process Material
# 92           United States  North America  Resources/Process Material
# 103             Luxembourg         Europe  Resources/Process Material
# 113          United States  North America  Resources/Process Material
# 121                  Spain         Europe                        TIME
# 126          United States  North America                        TIME
# 136          United States  North America                        TIME
# 142                 Norway         Europe  Resources/Process Material
# 143         United Kingdom         Europe                    Services
# 154                 France         Europe                 Engineering
# 161          United States  North America  Resources/Process Material
# 177          United States  North America       Auto & Transportation
# 178          United States  North America  Resources/Process Material
# 181          United States  North America                        TIME
# 185              Singapore   Asia-Pacific  Resources/Process Material
# 196            South Korea   Asia-Pacific  Resources/Process Material
# 198            South Korea   Asia-Pacific       Auto & Transportation
# 203                 France         Europe                 Engineering
# 240                  Spain         Europe  Resources/Process Material
# 290          United States  North America  Resources/Process Material
# 319          United States  North America       Auto & Transportation
# 324          United States  North America                    Services
# 329          United States  North America  Resources/Process Material
# 343          United States  North America                    Services
# 360                Austria         Europe  Resources/Process Material
# 361                  Italy         Europe                        TIME
# 368            South Korea   Asia-Pacific                        TIME
# 384          United States  North America                    Services
# ...                    ...            ...                         ...
# 6318         United States  North America                    Services
# 6335                France         Europe                    Services
# 6357        United Kingdom         Europe  Resources/Process Material
# 6372         United States  North America                    Services
# 6401             Australia   Asia-Pacific                    Services
# 6464                Taiwan   Asia-Pacific                        TIME
# 6472  United Arab Emirates  Rest of World                    Services
# 6476                 India       Emerging  Resources/Process Material
# 6504        United Kingdom         Europe                    Services
# 6532           South Korea   Asia-Pacific  Resources/Process Material
# 6533                 Japan   Asia-Pacific                    Services
# 6550                 China   Asia-Pacific  Resources/Process Material
# 6566                France         Europe                    Services
# 6581                 China   Asia-Pacific                        TIME
# 6597        United Kingdom         Europe       Auto & Transportation
# 6599              Malaysia   Asia-Pacific  Resources/Process Material
# 6606             Australia   Asia-Pacific  Resources/Process Material
# 6635             Hong Kong   Asia-Pacific                    Services
# 6677             Indonesia   Asia-Pacific  Resources/Process Material
# 6688                 China   Asia-Pacific  Resources/Process Material
# 6740         United States  North America                    Services
# 6768                Taiwan   Asia-Pacific                 Engineering
# 6837         United States  North America                    Services
# 6856         United States  North America                        TIME
# 6876        United Kingdom         Europe                    Services
# 6941                 Japan   Asia-Pacific                    Services
# 6953           South Korea   Asia-Pacific                        TIME
# 7044                 Spain         Europe                    Services
# 7092         United States  North America  Resources/Process Material
# 7124                 Japan   Asia-Pacific                    Services
#
#                    AV Sector       FY2013       FY2014       FY2015
# 3                  Oil & Gas       451235       421105       264960
# 6                  Oil & Gas       390247       364763       236810
# 37                 Oil & Gas       211665       192308       122566
# 92                      Food        89804        81201        67702
# 103                    Steel        79440        79282        63578
# 113                   Pharma        51584        49605        48851
# 121       Telecome Operators  60867.96424  53814.83431  51012.75239
# 126        Tech HW Equipment        57371        55123        52107
# 136        Tech HW Equipment       112298       111454       103355
# 142                Oil & Gas   73165.8059  71665.87735  54106.91589
# 143       Financial Services        58404        57277        56018
# 154             Construction  44213.57181  43192.00422  42107.33262
# 161                 Beverage        46854        45998        44294
# 177                Truck OEM        55656        55184        47011
# 178                   Pharma        44033        42237        39498
# 181                   Retail  49183.63227        42410        40339
# 185                     Food    44085.001    43084.875    38776.635
# 196                Oil & Gas  58117.55577  57416.46759  42226.33474
# 198                Truck OEM  47237.17245  45837.44889  40371.05826
# 203             Construction  35182.53552  34976.32826  34558.97981
# 240                Oil & Gas  52232.50922  41835.87586  35634.43145
# 290                Chemicals        31217        29767        26794
# 319                Aerospace        24661        23979        23526
# 324                   Retail        39854        36188        31198
# 329                Oil & Gas        56632        55336        30299
# 343                Insurance        23619        22609        20891
# 360                Oil & Gas   44623.5655  37783.27197  23939.42614
# 361       Telecome Operators  24775.38138  22957.39085  21100.95643
# 368       Telecome Operators  20971.88037  20683.77231  19822.26335
# 384                   Retail     24380.51    23114.263     22492.36
# ...                      ...          ...          ...          ...
# 6318      Financial Services     1528.615      1184.05     1000.653
# 6335  Trading & Distribution     685.7696    621.72015    581.33369
# 6357          Precious Metal      622.158      492.951      469.146
# 6372              Publishing       674.74      656.697      648.543
# 6401                Printing    739.36202    681.32899    616.26452
# 6464       Tech HW Equipment    760.85861     698.5842    637.92014
# 6472      Financial Services    652.49251     635.8833    576.44804
# 6476               Chemicals    867.78625    771.78865    749.24029
# 6504      Financial Services    1757.8101   1668.20107   1516.96509
# 6532                   Steel     715.7704    651.30834    597.76006
# 6533             Restaurants    679.13969    639.23761    616.95729
# 6550                    Food    734.96197    647.93019    562.31209
# 6566                  Retail    580.89848    572.34508    562.67907
# 6581       Tech HW Equipment       91.166     71.26107    256.20778
# 6597               Aerospace    767.07789    494.81372    460.83006
# 6599                   Steel    634.84494    632.74486    568.51444
# 6606                  Energy    600.99561    534.40294    490.55349
# 6635             Real Estate    741.70976    727.32051    649.82461
# 6677                  Energy    694.91267    607.42656    565.61529
# 6688                Aluminum    815.37654    762.23263    673.76484
# 6740             Health Care      504.768       210.14      117.239
# 6768            Construction    633.49899     559.5303    508.11606
# 6837               Education      768.623      638.705      561.729
# 6856       Tech HW Equipment      563.412      530.251      505.595
# 6876             Restaurants    561.71362    550.05217    513.96048
# 6941                  Retail    504.25773    497.18481    481.49957
# 6953       Tech HW Equipment    495.25167     409.3535    395.66708
# 7044              Publishing    556.75539    520.31457    496.49522
# 7092    Personal & Household      563.579      499.261       468.54
# 7124  Trading & Distribution    734.47279    675.81744    592.46732
#
# [337 rows x 9 columns]

# %%
#Find the suckers that appear in all lists
sucker_bag=[]
for idea in list(temp_db.keys()):
    sucker_bag = sucker_bag + list(temp_db[idea]["Company Name"])
len(sucker_bag)
# Out:
# 1008

# %%
(set(sucker_bag))
# Out:
# {'ABB Ltd. (SWX:ABBN)',
#  'ABC-Mart, Inc. (TSE:2670)',
#  'ADTRAN, Inc. (NasdaqGS:ADTN)',
#  'AF Gruppen ASA (OB:AFG)',
#  'ALBIS Co., Ltd. (TSE:7475)',
#  'AP (Thailand) Public Company Limited (SET:AP)',
#  'ASKUL Corporation (TSE:2678)',
#  'AT&T Inc. (NYSE:T)',
#  'Abercrombie & Fitch Co. (NYSE:ANF)',
#  'Abertis Infraestructuras S.A. (BME:ABE)',
#  'Abu Dhabi Aviation (ADX:ADAVIATION)',
#  'AcadeMedia AB (OM:ACAD)',
#  'Accell Group N.V. (ENXTAM:ACCEL)',
#  'Achilles Corporation (TSE:5142)',
#  'Acom Co., Ltd. (TSE:8572)',
#  'Adcorp Holdings Limited (JSE:ADR)',
#  'Advantech Co., Ltd. (TSEC:2395)',
#  'Affinion Group Holdings, Inc. (OTCPK:AFGR)',
#  'Ajinomoto Co., Inc. (TSE:2802)',
#  'Akka Technologies (ENXTPA:AKA)',
#  'Al Ezz Dekheila Steel Company - Alexandria S.A.E. (CASE:IRAX)',
#  'Al Rajhi Banking and Investment Corporation (SASE:1120)',
#  'Alexander Forbes Group Holdings Limited (JSE:AFH)',
#  'Alfa Laval AB (publ) (OM:ALFA)',
#  'Alfresa Holdings Corporation (TSE:2784)',
#  'Alliance Healthcare Services, Inc. (NasdaqGM:AIQ)',
#  'Allscripts Healthcare Solutions, Inc. (NasdaqGS:MDRX)',
#  'Alltek Technology Corporation (TSEC:3209)',
#  'Almirall, S.A. (BME:ALM)',
#  'Alno AG (DB:ANO)',
#  'AmTrust Financial Services, Inc. (NasdaqGS:AFSI)',
#  'Amedisys, Inc. (NasdaqGS:AMED)',
#  'América Móvil, S.A.B. de C.V. (BMV:AMX L)',
#  'Arabtec Holding PJSC (DFM:ARTC)',
#  'Arbonia AG (SWX:ARBN)',
#  'Arcadyan Technology Corporation (TSEC:3596)',
#  'ArcelorMittal (ENXTAM:MT)',
#  'Arcos Dorados Holdings Inc. (NYSE:ARCO)',
#  'Arcplus Group PLC (SHSE:600629)',
#  'Asahi Group Holdings, Ltd. (TSE:2502)',
#  'Asseco Poland S.A. (WSE:ACP)',
#  'Astellas Pharma Inc. (TSE:4503)',
#  'Atlantia S.p.A. (BIT:ATL)',
#  'Atlas Honda Limited (KASE:ATLH)',
#  'Atmos Energy Corporation (NYSE:ATO)',
#  'Automatic Data Processing, Inc. (NasdaqGS:ADP)',
#  'Automotive Holdings Group Limited (ASX:AHG)',
#  'Aveng Limited (JSE:AEG)',
#  'Avista Corporation (NYSE:AVA)',
#  'Avon Products, Inc. (NYSE:AVP)',
#  'BAUER Aktiengesellschaft (XTRA:B5A)',
#  'BTG Hotels (Group) Co., Ltd. (SHSE:600258)',
#  'Ballarpur Industries Limited (BSE:500102)',
#  'Banco Bilbao Vizcaya Argentaria, S.A. (BME:BBVA)',
#  'Banco Popular Español, S.A. (BME:POP)',
#  'Barnes & Noble, Inc. (NYSE:BKS)',
#  'Beijer Ref AB (publ) (OM:BEIJ B)',
#  'Beijing Hualian Hypermarket Co., Ltd. (SHSE:600361)',
#  'Beijing Jingkelong Company Limited (SEHK:814)',
#  'Beijing Teamsun Technology Co., Ltd. (SHSE:600410)',
#  'Bharti Airtel Limited (BSE:532454)',
#  'Billabong International Limited (ASX:BBG)',
#  'BioMarin Pharmaceutical Inc. (NasdaqGS:BMRN)',
#  'BioScrip, Inc. (NasdaqGS:BIOS)',
#  'Bitauto Holdings Limited (NYSE:BITA)',
#  'Black Box Corporation (NasdaqGS:BBOX)',
#  'BlackBerry Limited (TSX:BB)',
#  'Blackbaud, Inc. (NasdaqGS:BLKB)',
#  'Boral Limited (ASX:BLD)',
#  'Bouygues SA (ENXTPA:EN)',
#  'Brambles Limited (ASX:BXB)',
#  'Bravida Holding AB (publ) (OM:BRAV)',
#  'Bremer Lagerhaus Gesellschaft Aktiengesellschaft von 1877 (DB:BLH)',
#  'Brickworks Limited (ASX:BKW)',
#  'Brinker International, Inc. (NYSE:EAT)',
#  'Broadridge Financial Solutions, Inc. (NYSE:BR)',
#  'Brookfield Renewable Partners L.P. (TSX:BEP.UN)',
#  'Brown & Brown, Inc. (NYSE:BRO)',
#  'Burckhardt Compression Holding AG (SWX:BCHN)',
#  'Buzzi Unicem SpA (BIT:BZU)',
#  'CAC Holdings Corporation (TSE:4725)',
#  'CCL Industries Inc. (TSX:CCL.B)',
#  'CEZ, a. s. (SEP:CEZ)',
#  'CITIC Guoan Information Industry Co., Ltd. (SZSE:000839)',
#  'CJ CGV Co., Ltd. (KOSE:A079160)',
#  'CJ Corporation (KOSE:A001040)',
#  'CLP Holdings Limited (SEHK:2)',
#  'CME Group Inc. (NasdaqGS:CME)',
#  'CMIC HOLDINGS Co., Ltd. (TSE:2309)',
#  'COSMOS Pharmaceutical Corporation (TSE:3349)',
#  'CSBC Corporation, Taiwan (TSEC:2208)',
#  'CSG Systems International, Inc. (NasdaqGS:CSGS)',
#  'CSSC Offshore & Marine Engineering (Group) Company Limited (SEHK:317)',
#  'CTEEP - Companhia de Transmissão de Energia Elétrica Paulista (BOVESPA:TRPL4)',
#  'CTT - Correios De Portugal, S.A. (ENXTLS:CTT)',
#  'CVS Health Corporation (NYSE:CVS)',
#  'CYBG PLC (LSE:CYBG)',
#  'Cachet Pharmaceutical Co., Ltd. (SZSE:002462)',
#  'Cal-Comp Electronics (Thailand) Public Company Limited (SET:CCET)',
#  'Cal-Maine Foods, Inc. (NasdaqGS:CALM)',
#  'California Water Service Group (NYSE:CWT)',
#  'Caltagirone SpA (BIT:CALT)',
#  'Cameco Corporation (TSX:CCO)',
#  'Canon Inc. (TSE:7751)',
#  'Cap Gemini S.A. (ENXTPA:CAP)',
#  'Casio Computer Co., Ltd. (TSE:6952)',
#  'Cheil Worldwide Inc. (KOSE:A030000)',
#  'Chesapeake Energy Corporation (NYSE:CHK)',
#  'China Baoan Group Co., Ltd. (SZSE:000009)',
#  'China First Heavy Industries (SHSE:601106)',
#  'China Gezhouba Group Company Limited (SHSE:600068)',
#  'China Haisum Engineering Co., Ltd. (SZSE:002116)',
#  "China Nonferrous Metal Industry's Foreign Engineering and Construction Co.,Ltd. (SZSE:000758)",
#  'China Railway Erju Co., Ltd. (SHSE:600528)',
#  'Chiyoda Co., Ltd. (TSE:8185)',
#  'Chiyoda Corporation (TSE:6366)',
#  'Choice Hotels International, Inc. (NYSE:CHH)',
#  'Chongqing Iron & Steel Company Limited (SEHK:1053)',
#  'Chongqing Taiji Industry (Group) Co.,Ltd (SHSE:600129)',
#  'Chongqing Water Group Co.,Ltd. (SHSE:601158)',
#  'Chongqing Zongshen Power Machinery Co.,Ltd (SZSE:001696)',
#  'Choppies Enterprises Limited (BSM:CHOPPIES)',
#  'Chunghwa Telecom Co., Ltd. (TSEC:2412)',
#  'Ciech S.A. (WSE:CIE)',
#  'Cimarex Energy Co. (NYSE:XEC)',
#  'Cisco Systems, Inc. (NasdaqGS:CSCO)',
#  'Citrix Systems, Inc. (NasdaqGS:CTXS)',
#  'Cleanaway Waste Management Limited (ASX:CWY)',
#  'Codere, S.A. (BME:CDR)',
#  'Cognizant Technology Solutions Corporation (NasdaqGS:CTSH)',
#  'Colfax Corporation (NYSE:CFX)',
#  'Comfort Systems USA, Inc. (NYSE:FIX)',
#  'Community Health Systems, Inc. (NYSE:CYH)',
#  'Compagnie des Alpes SA (ENXTPA:CDA)',
#  'Companhia de Tecidos Norte de Minas (BOVESPA:CTNM4)',
#  'Consolidated Communications Holdings, Inc. (NasdaqGS:CNSL)',
#  'Constellation Brands, Inc. (NYSE:STZ)',
#  'Constellation Software Inc. (TSX:CSU)',
#  'Contact Energy Limited (NZSE:CEN)',
#  'Coolpad Group Limited (SEHK:2369)',
#  'Corporacion Aceros Arequipa S.A. (BVL:CORAREI1)',
#  'Corporativo Fragua, S.A.B. De C.V. (BMV:FRAGUA B)',
#  'Coteccons Construction Joint Stock Company (HOSE:CTD)',
#  'Coway Co., Ltd. (KOSE:A021240)',
#  'Cowell e Holdings Inc. (SEHK:1415)',
#  'Credit Saison Co.,Ltd. (TSE:8253)',
#  'Cross Country Healthcare, Inc. (NasdaqGS:CCRN)',
#  'DCC plc (LSE:DCC)',
#  'DENTSPLY SIRONA Inc. (NasdaqGS:XRAY)',
#  'DH Corporation (TSX:DH)',
#  'DHC Software Co., Ltd. (SZSE:002065)',
#  'DNA Ltd. (HLSE:DNA)',
#  'DOUTOR NICHIRES Holdings Co., Ltd. (TSE:3087)',
#  'Daehan Steel Co., Ltd. (KOSE:A084010)',
#  'Daelim Industrial Co., Ltd. (KOSE:A000210)',
#  'Daesung Group Partners.Co.,Ltd. (KOSE:A005620)',
#  'Daesung Industrial Co., Ltd. (KOSE:A128820)',
#  'Daewoong Pharmaceutical Co., Ltd. (KOSE:A069620)',
#  'Dai Nippon Printing Co., Ltd. (TSE:7912)',
#  'Daisue Construction Co., Ltd. (TSE:1814)',
#  'Daisui Co., Ltd. (TSE:7538)',
#  'Daisyo Corporation (TSE:9979)',
#  'Daphne International Holdings Limited (SEHK:210)',
#  'Daqin Railway Co., Ltd. (SHSE:601006)',
#  'Dar Al Arkan Real Estate Development Company (SASE:4300)',
#  'Dare Power Dekor Home Co., Ltd. (SZSE:000910)',
#  'Debenhams plc (LSE:DEB)',
#  'Deckers Outdoor Corporation (NYSE:DECK)',
#  "Denny's Corporation (NasdaqCM:DENN)",
#  'Deutsche Börse Aktiengesellschaft (XTRA:DB1)',
#  'Deutsche Telekom AG (DB:DTE)',
#  'Devoteam S.A. (ENXTPA:DVT)',
#  'DigitalGlobe, Inc. (NYSE:DGI)',
#  'Dimed S.A. Distribuidora de Medicamentos (BOVESPA:PNVL4)',
#  'DineEquity, Inc. (NYSE:DIN)',
#  'Dr. Peng Telecom & Media Group Co., Ltd. (SHSE:600804)',
#  'Drake & Scull International PJSC (DFM:DSI)',
#  'Dubai Islamic Bank P.J.S.C (DFM:DIB)',
#  'Duskin Co., Ltd. (TSE:4665)',
#  'Dynegy Inc. (NYSE:DYN)',
#  'E1 Corporation (KOSE:A017940)',
#  'EOG Resources, Inc. (NYSE:EOG)',
#  'EPAM Systems, Inc. (NYSE:EPAM)',
#  'EPS Holdings, Inc. (TSE:4282)',
#  'ESCO Technologies Inc. (NYSE:ESE)',
#  'East African Breweries Limited (NASE:EABL.O)',
#  'East Japan Railway Company (TSE:9020)',
#  'Eastman Kodak Company (NYSE:KODK)',
#  'Eisai Co., Ltd. (TSE:4523)',
#  'Electrocomponents plc (LSE:ECM)',
#  'Elia System Operator SA (ENXTBR:ELI)',
#  'Embotelladora Andina S.A. (SNSE:ANDINA-B)',
#  'Empresa de Telecomunicaciones de Bogotá S.A. E.S.P. (BVC:ETB)',
#  'Enel SpA (BIT:ENEL)',
#  'Ennis, Inc. (NYSE:EBF)',
#  'Envision Healthcare Corporation (NYSE:EVHC)',
#  'Equatorial Energia S.A. (BOVESPA:EQTL3)',
#  'Esprit Holdings Limited (SEHK:330)',
#  'Esterline Technologies Corporation (NYSE:ESL)',
#  'Etn. Fr. Colruyt NV (ENXTBR:COLR)',
#  'Euro Disney S.C.A. (ENXTPA:EDL)',
#  'Exelon Corporation (NYSE:EXC)',
#  'FRoSTA Aktiengesellschaft (DB:NLM)',
#  'FTI Consulting, Inc. (NYSE:FCN)',
#  'Fairfax Media Limited (ASX:FXJ)',
#  'Fairpoint Communications, Inc. (NasdaqCM:FRP)',
#  'Federal Signal Corporation (NYSE:FSS)',
#  'Fielmann AG (DB:FIE)',
#  'Findel plc (LSE:FDL)',
#  'First Data Corporation (NYSE:FDC)',
#  'First Solar, Inc. (NasdaqGS:FSLR)',
#  'Five Star Quality Care, Inc. (NasdaqCM:FVE)',
#  'Fletcher Building Limited (NZSE:FBU)',
#  'Folli-Follie Commercial Manufacturing and Technical Societe Anonyme (ATSE:FFGRP)',
#  'Forte Oil Plc (NGSE:FO)',
#  'Fred. Olsen Energy ASA (OB:FOE)',
#  'Fudo Tetra Corporation (TSE:1813)',
#  'Fuji Furukawa Engineering & Construction Co.Ltd. (TSE:1775)',
#  'Fuji Kyuko Co., Ltd. (TSE:9010)',
#  'Fuji Soft Incorporated (TSE:9749)',
#  'Fujita Kanko Inc. (TSE:9722)',
#  'Fujitsu Limited (TSE:6702)',
#  'Futaba Industrial Co., Ltd. (TSE:7241)',
#  'GOME Electrical Appliances Holding Limited (SEHK:493)',
#  'GS Home Shopping Inc. (KOSDAQ:A028150)',
#  'Galenica Ltd. (SWX:GALN)',
#  'Galliford Try plc (LSE:GFRD)',
#  'Gamesa Corporación Tecnológica, S.A. (BME:GAM)',
#  'Garmin Ltd. (NasdaqGS:GRMN)',
#  'Gattaca plc (AIM:GATC)',
#  'Geberit AG (SWX:GEBN)',
#  'Gemdale Properties and Investment Corporation Limited (SEHK:535)',
#  'General Cable Corporation (NYSE:BGC)',
#  'Genomma Lab Internacional, S.A.B. de C.V. (BMV:LAB B)',
#  'Genting Malaysia Berhad (KLSE:GENM)',
#  'Geo Holdings Corporation (TSE:2681)',
#  'GlaxoSmithKline plc (LSE:GSK)',
#  'Global Payments Inc. (NYSE:GPN)',
#  'Global Top E-Commerce Co., Ltd. (SZSE:002640)',
#  'Globe Telecom, Inc. (PSE:GLO)',
#  'Globlex Holding Management Public Company Limited (SET:GBX)',
#  'GoHigh Data Networks Technology Co., Ltd. (SZSE:000851)',
#  'Gold Circuit Electronics Ltd. (TSEC:2368)',
#  'Goodbaby International Holdings Limited (SEHK:1086)',
#  'GraceKennedy Limited (JMSE:GK)',
#  'Great Eagle Holdings Limited (SEHK:41)',
#  'Greek Organisation of Football Prognostics S.A. (ATSE:OPAP)',
#  'Green Cross Holdings Corporation (KOSE:A005250)',
#  'Greif, Inc. (NYSE:GEF)',
#  'Grifols, S.A. (BME:GRF)',
#  'Grupa Zywiec S.A. (WSE:ZWC)',
#  'Grupo Bafar, S.A.B. de C.V. (BMV:BAFAR B)',
#  'Grupo Empresarial San José, S.A. (BME:GSJ)',
#  'Grupo Gigante, S. A. B. de C. V. (BMV:GIGANTE *)',
#  'Grupo Televisa, S.A.B. (BMV:TLEVISA CPO)',
#  'Guangdong Jingyi Metal Co., Ltd. (SZSE:002295)',
#  'Guangzhou Haige Communications Group Incorporated Company (SZSE:002465)',
#  'Gulf International Services  Q.S.C. (DSM:GISS)',
#  'Guotai Junan Securities Co.,Ltd. (SHSE:601211)',
#  'H&R Block, Inc. (NYSE:HRB)',
#  'H2O Retailing Corporation (TSE:8242)',
#  'HAL Trust (ENXTAM:HAL)',
#  'HCL Infosystems Limited (BSE:500179)',
#  'HOYA Corporation (TSE:7741)',
#  'HTC Corporation (TSEC:2498)',
#  'Halfords Group plc (LSE:HFD)',
#  'Halla Corporation (KOSE:A014790)',
#  'Hana Financial Group Inc. (KOSE:A086790)',
#  'Hangzhou Great Star Industrial Co., Ltd. (SZSE:002444)',
#  'Hanjin Heavy Industries & Construction Co., Ltd. (KOSE:A097230)',
#  'Hanjin Heavy Industries & Construction Holdings Co., Ltd. (KOSE:A003480)',
#  'Hanshin Engineering & Construction Co., Ltd. (KOSE:A004960)',
#  'Hansol Technics Co., Ltd. (KOSE:A004710)',
#  'Hanwa Co., Ltd. (TSE:8078)',
#  'Harmony Gold Mining Company Limited (JSE:HAR)',
#  'Heineken Holding N.V. (ENXTAM:HEIO)',
#  'Hellenic Telecommunications Organization S.A. (ATSE:HTO)',
#  'Henan Shenhuo Coal & Power Co.,Ltd (SZSE:000933)',
#  'Henry Schein, Inc. (NasdaqGS:HSIC)',
#  'Hillenbrand, Inc. (NYSE:HI)',
#  'Hitachi Koki Co., Ltd. (TSE:6581)',
#  'Hitejinro Holdings Co., Ltd. (KOSE:A000140)',
#  'Hologic, Inc. (NasdaqGS:HOLX)',
#  'Hon Hai Precision Industry Co., Ltd. (TSEC:2317)',
#  'Hong Kong Exchanges and Clearing Limited (SEHK:388)',
#  'Hopson Development Holdings Limited (SEHK:754)',
#  'Hosken Consolidated Investments Limited (JSE:HCI)',
#  'House Foods Group Inc. (TSE:2810)',
#  'Hudbay Minerals Inc. (TSX:HBM)',
#  'Hulic Co., Ltd. (TSE:3003)',
#  'Humana Inc. (NYSE:HUM)',
#  'Hutchison Port Holdings Trust (SGX:NS8U)',
#  'Hyflux Ltd (SGX:600)',
#  'Hyosung Corporation (KOSE:A004800)',
#  'Hyundai Department Store Co., Ltd. (KOSE:A069960)',
#  'Hyundai Livart Furniture Company Limited (KOSE:A079430)',
#  'IDOM Inc. (TSE:7599)',
#  'Iino Kaiun Kaisha, Ltd. (TSE:9119)',
#  'Inapa - Investimentos, Participações e Gestão, SA (ENXTLS:INA)',
#  'Industrial Bank of Korea (KOSE:A024110)',
#  'Ingenico Group (ENXTPA:ING)',
#  'Ingles Markets, Incorporated (NasdaqGS:IMKT.A)',
#  'InnerWorkings, Inc. (NasdaqGS:INWK)',
#  'Innophos Holdings, Inc. (NasdaqGS:IPHS)',
#  'Inter Pipeline Ltd. (TSX:IPL)',
#  'International Speedway Corporation (NasdaqGS:ISCA)',
#  'Intime Retail (Group) Company Limited (SEHK:1833)',
#  'Intralot S.A. (ATSE:INLOT)',
#  'Investment Technology Group, Inc. (NYSE:ITG)',
#  'Inwido AB (OM:INWI)',
#  'J&P-Avax S.A. (ATSE:AVAX)',
#  'J. Front Retailing Co., Ltd. (TSE:3086)',
#  'JAKKS Pacific, Inc. (NasdaqGS:JAKK)',
#  'JBCC Holdings Inc. (TSE:9889)',
#  'JVC KENWOOD Corporation (TSE:6632)',
#  'JW Holdings Corporation (KOSE:A096760)',
#  'Jack in the Box Inc. (NasdaqGS:JACK)',
#  'Japan Airport Terminal Co., Ltd. (TSE:9706)',
#  'Japan Exchange Group, Inc. (TSE:8697)',
#  'Jiangsu Akcome Science and Technology Co., Ltd. (SZSE:002610)',
#  'Jiangsu Hongtu High Technology Co., Ltd. (SHSE:600122)',
#  'Jiangxi Copper Company Limited (SEHK:358)',
#  'JiaoZuo WanFang Aluminum Manufacturing Co., Ltd (SZSE:000612)',
#  'Jingwei Textile Machinery Company Limited (SZSE:000666)',
#  'JinkoSolar Holding Co., Ltd. (NYSE:JKS)',
#  'Jinling Pharmaceutical Company Limited (SZSE:000919)',
#  'Johnson & Johnson (NYSE:JNJ)',
#  'Joyoung Co.,Ltd (SZSE:002242)',
#  'Julius Baer Group Ltd. (SWX:BAER)',
#  'Jumbo S.A. (ATSE:BELA)',
#  'Just Energy Group Inc. (TSX:JE)',
#  'KB Financial Group Inc. (KOSE:A105560)',
#  'KITZ Corporation (TSE:6498)',
#  'KOSÉ Corporation (TSE:4922)',
#  'KPX Holdings Co.,Ltd. (KOSE:A092230)',
#  'KT&G Corporation (KOSE:A033780)',
#  'Kaga Electronics Co.,Ltd. (TSE:8154)',
#  'Kajima Corporation (TSE:1812)',
#  'Kalpataru Power Transmission Limited (BSE:522287)',
#  'Kameda Seika CO., Ltd. (TSE:2220)',
#  'Kanaden Corporation (TSE:8081)',
#  'Kandenko Co., Ltd. (TSE:1942)',
#  'KappAhl AB (publ) (OM:KAHL)',
#  'Kate Spade & Company (NYSE:KATE)',
#  'Keikyu Corporation (TSE:9006)',
#  'Keio Corporation (TSE:9008)',
#  'Keisei Electric Railway Co., Ltd. (TSE:9009)',
#  'Kering S.A. (ENXTPA:KER)',
#  'Kesoram Industries Limited (BSE:502937)',
#  'Keyence Corporation (TSE:6861)',
#  'Kikkoman Corporation (TSE:2801)',
#  'Kimberly-Clark de México, S. A. B. de C. V. (BMV:KIMBER A)',
#  'Kindred Group plc (OM:KIND SDB)',
#  'Kintetsu Group Holdings Co., Ltd. (TSE:9041)',
#  'Kirindo Holdings Co., Ltd. (TSE:3194)',
#  'Kitano Construction Corp. (TSE:1866)',
#  'Kobayashi Pharmaceutical Co., Ltd. (TSE:4967)',
#  'Konica Minolta, Inc. (TSE:4902)',
#  'Koninklijke KPN N.V. (ENXTAM:KPN)',
#  'KrKa, d.d. (LJSE:KRKG)',
#  'Kuala Lumpur Kepong Berhad (KLSE:KLK)',
#  'Kudelski SA (SWX:KUD)',
#  'Kureha Corporation (TSE:4023)',
#  'Kyodo Printing Co., Ltd. (TSE:7914)',
#  'Kyokuto Boeki Kaisha, Ltd. (TSE:8093)',
#  'Kyowa Exeo Corporation (TSE:1951)',
#  'Kyungdong City Gas Co., Ltd. (KOSE:A012320)',
#  'Kyushu Electric Power Company, Incorporated (TSE:9508)',
#  'LG Uplus Corp. (KOSE:A032640)',
#  'LHC Group, Inc. (NasdaqGS:LHCG)',
#  'LSIS Co., Ltd. (KOSE:A010120)',
#  'Ladenburg Thalmann Financial Services Inc. (AMEX:LTS)',
#  'LafargeHolcim Ltd. (SWX:LHN)',
#  'Laurentian Bank of Canada (TSX:LB)',
#  'Layne Christensen Company (NasdaqGS:LAYN)',
#  'Leoch International Technology Limited (SEHK:842)',
#  "Leon's Furniture Limited (TSX:LNF)",
#  'Leshi Internet Information & Technology Corp., Beijing (SZSE:300104)',
#  'Li & Fung Limited (SEHK:494)',
#  'Li Ning Company Limited (SEHK:2331)',
#  'LifePoint Health, Inc. (NasdaqGS:LPNT)',
#  'Light S.A. (BOVESPA:LIGT3)',
#  'Livzon Pharmaceutical Group Inc. (SZSE:000513)',
#  'Loblaw Companies Limited (TSX:L)',
#  'Logitech International SA (SWX:LOGN)',
#  'Lonza Group Ltd (SWX:LONN)',
#  'Lotte Fine Chemical Co., Ltd. (KOSE:A004000)',
#  'Lupin Limited (BSE:500257)',
#  'M1 Limited (SGX:B2F)',
#  'MARUICHI Co.,Ltd. (NSE:8228)',
#  'MCJ Co., Ltd. (TSE:6670)',
#  'MEDNAX, Inc. (NYSE:MD)',
#  'MGIC Investment Corporation (NYSE:MTG)',
#  'MGM Resorts International (NYSE:MGM)',
#  'MHP S.A. (LSE:MHPC)',
#  'MIRAIT Holdings Corporation (TSE:1417)',
#  'MMTC Limited (BSE:513377)',
#  'MRS Logística S.A. (SOMA:MRSA3B)',
#  'MRV Engenharia e Participações S.A. (BOVESPA:MRVE3)',
#  'MTU Aero Engines AG (XTRA:MTX)',
#  'Macquarie Infrastructure Corporation (NYSE:MIC)',
#  'Mail.Ru Group Limited (LSE:MAIL)',
#  'Makiya Co., Ltd. (JASDAQ:9890)',
#  'Malakoff Corporation Berhad (KLSE:MALAKOF)',
#  'Manitoba Telecom Services Inc. (TSX:MBT)',
#  'ManpowerGroup Inc. (NYSE:MAN)',
#  'Maple Leaf Foods Inc. (TSX:MFI)',
#  'Marfrig Global Foods S.A. (BOVESPA:MRFG3)',
#  'Marriott Vacations Worldwide Corporation (NYSE:VAC)',
#  'Martin Marietta Materials, Inc. (NYSE:MLM)',
#  'Matsuya Co., Ltd. (TSE:8237)',
#  'Matthews International Corporation (NasdaqGS:MATW)',
#  'Max Co., Ltd. (TSE:6454)',
#  "McDonald's Holdings Company (Japan), Ltd. (JASDAQ:2702)",
#  'MediPal Holdings Corporation (TSE:7459)',
#  'Meiko Electronics Co., Ltd. (JASDAQ:6787)',
#  'Merit Medical Systems, Inc. (NasdaqGS:MMSI)',
#  'Meritz Fire & Marine Insurance Co., Ltd. (KOSE:A000060)',
#  'MicroStrategy Incorporated (NasdaqGS:MSTR)',
#  'Mie Kotsu Group Holdings, Inc. (TSE:3232)',
#  'Millcon Steel Public Company Limited (SET:MILL)',
#  'Mineral Resources Limited (ASX:MIN)',
#  'Minsur S.A. (BVL:MINSURI1)',
#  'Mirae Asset Life Insurance Co., Ltd. (KOSE:A085620)',
#  'Mitsubishi Logistics Corporation (TSE:9301)',
#  'Mitsubishi Paper Mills Limited (TSE:3864)',
#  'Mitsubishi Research Institute, Inc. (TSE:3636)',
#  'Mitsubishi UFJ Lease & Finance Company Limited (TSE:8593)',
#  'Miura Co., Ltd. (TSE:6005)',
#  'Mixi, Inc. (TSE:2121)',
#  'Mobile Mini, Inc. (NasdaqGS:MINI)',
#  'MoneyGram International, Inc. (NasdaqGS:MGI)',
#  'Moorim Paper Co., Ltd. (KOSE:A009200)',
#  'Morinaga & Co., Ltd. (TSE:2201)',
#  'Morningstar, Inc. (NasdaqGS:MORN)',
#  'Motherson Sumi Systems Limited (BSE:517334)',
#  'Mpact Limited (JSE:MPT)',
#  'Mullen Group Ltd. (TSX:MTL)',
#  'Myhome Real Estate Development Group Co., Ltd. (SZSE:000667)',
#  'N Brown Group plc (LSE:BWNG)',
#  'NEC Corporation (TSE:6701)',
#  'NEX Group plc (LSE:NXG)',
#  'NGK Insulators, Ltd. (TSE:5333)',
#  'NGL Energy Partners LP (NYSE:NGL)',
#  'NII Holdings, Inc. (NasdaqGS:NIHD)',
#  'NRG Energy, Inc. (NYSE:NRG)',
#  'NS United Kaiun Kaisha, Ltd. (TSE:9110)',
#  'NSD Co., Ltd. (TSE:9759)',
#  'NVH Korea Inc. (KOSDAQ:A067570)',
#  'Nac Co., Ltd. (TSE:9788)',
#  'Nagoya Railroad Co., Ltd. (TSE:9048)',
#  'Nakano Corporation (TSE:1827)',
#  'Nasdaq, Inc. (NasdaqGS:NDAQ)',
#  'National Bank of Greece S.A. (ATSE:ETE)',
#  'National Bank of Pakistan (KASE:NBP)',
#  'National Petroleum Co., Ltd. (TSEC:9937)',
#  'Net 1 UEPS Technologies, Inc. (NasdaqGS:UEPS)',
#  'New Hua Du Supercenter Co.,Ltd. (SZSE:002264)',
#  'New Media Investment Group Inc. (NYSE:NEWM)',
#  'New Oriental Education & Technology Group Inc. (NYSE:EDU)',
#  'Newfield Exploration Company (NYSE:NFX)',
#  'NiSource Inc. (NYSE:NI)',
#  'Nichi-Iko Pharmaceutical Co., Ltd. (TSE:4541)',
#  'Nihon Yamamura Glass Co., Ltd. (TSE:5210)',
#  'Nintendo Co., Ltd. (TSE:7974)',
#  'Nippon Light Metal Holdings Company, Ltd. (TSE:5703)',
#  'Nippon Sheet Glass Co., Ltd. (TSE:5202)',
#  'Nippon Signal Co., Ltd. (TSE:6741)',
#  'Nippon Soda Co., Ltd. (TSE:4041)',
#  'Nishimatsuya Chain Co., Ltd. (TSE:7545)',
#  'Nissan Tokyo Sales Holdings Co., Ltd. (TSE:8291)',
#  'Nissha Printing Co. Ltd. (TSE:7915)',
#  'Nobia AB (publ) (OM:NOBI)',
#  'Noble Group Limited (SGX:N21)',
#  'Nokia Corporation (HLSE:NOKIA)',
#  'Nomura Research Institute, Ltd. (TSE:4307)',
#  'NongShim Co., Ltd. (KOSE:A004370)',
#  'Norske Skogindustrier ASA (OB:NSG)',
#  'North Huajin Chemical Industries Co.,Ltd (SZSE:000059)',
#  'Norway Royal Salmon AS (OB:NRS)',
#  'Novartis AG (SWX:NOVN)',
#  'Nutrisystem, Inc. (NasdaqGS:NTRI)',
#  "O'Key Group S.A. (LSE:OKEY)",
#  'OMV Aktiengesellschaft (WBAG:OMV)',
#  'Obayashi Road Corporation (TSE:1896)',
#  'Odakyu Electric Railway Co., Ltd. (TSE:9007)',
#  'Odfjell SE (OB:ODF)',
#  'Oenon  Holdings, Inc. (TSE:2533)',
#  'Office Depot, Inc. (NasdaqGS:ODP)',
#  'Oki Electric Industry Co., Ltd. (TSE:6703)',
#  'Okumura Corporation (TSE:1833)',
#  'Olympic Group Corporation (TSE:8289)',
#  'Oman Telecommunications Company SAOG (MSM:OTEL)',
#  'Ono Pharmaceutical Co., Ltd. (TSE:4528)',
#  'Onward Holdings Co., Ltd. (TSE:8016)',
#  'Orange (ENXTPA:ORA)',
#  'Organización Cultiba, S.A.B. de C.V. (BMV:CULTIBA B)',
#  'Orient Corporation (TSE:8585)',
#  'Oriflame Holding AG (OM:ORI)',
#  'Owens-Illinois, Inc. (NYSE:OI)',
#  'PBG S.A. (WSE:PBG)',
#  'PC Depot Corporation (TSE:7618)',
#  'PCB NV (ENXTBR:PCBB)',
#  'PCCW Limited (SEHK:8)',
#  'PKC Group Oyj (HLSE:PKC1V)',
#  'PMP Limited (ASX:PMP)',
#  'PORR AG (WBAG:POS)',
#  'POSCO (KOSE:A005490)',
#  'PT Delta Dunia Makmur Tbk (JKSE:DOID)',
#  'PT Telekomunikasi Indonesia Tbk (JKSE:TLKM)',
#  'Pacific Basin Shipping Limited (SEHK:2343)',
#  'Pampa Energía S.A. (BASE:PAMP)',
#  'Pandora A/S (CPSE:PNDORA)',
#  'Pang Da Automobile Trade Co., Ltd (SHSE:601258)',
#  'Partner Communications Company Ltd. (NasdaqGS:PTNR)',
#  'Partron Co., Ltd. (KOSDAQ:A091700)',
#  'Patel Engineering Limited (BSE:531120)',
#  'Patterson Companies, Inc. (NasdaqGS:PDCO)',
#  'Peab AB (OM:PEAB B)',
#  'Pembina Pipeline Corporation (TSX:PPL)',
#  'Pennon Group Plc (LSE:PNN)',
#  'Petrol, Slovenska energetska druzba, d.d. (LJSE:PETG)',
#  'Pierre & Vacances SA (ENXTPA:VAC)',
#  'Pitney Bowes Inc. (NYSE:PBI)',
#  'Plantronics, Inc. (NYSE:PLT)',
#  'Porto Seguro S.A. (BOVESPA:PSSA3)',
#  'Premier Investments Limited (ASX:PMV)',
#  'Premium Brands Holdings Corporation (TSX:PBH)',
#  'Primary Health Care Limited (ASX:PRY)',
#  'Prism Cement Limited (BSE:500338)',
#  'Promotora de Informaciones, S.A. (BME:PRS)',
#  'Public Joint Stock Company Magnit (MISX:MGNT)',
#  'Pulmuone Co., Ltd. (KOSE:A017810)',
#  'Qatar Gas Transport Company Limited (Nakilat) Q.S.C. (DSM:QGTS)',
#  'Qingdao TGOOD Electric Co., Ltd. (SZSE:300001)',
#  'Qisda Corporation (TSEC:2352)',
#  'R1 RCM Inc. (OTCPK:ACHI)',
#  'RENESAS EASTON Co., Ltd. (TSE:9995)',
#  'RPS Group plc (LSE:RPS)',
#  'Radiant Logistics, Inc. (AMEX:RLGT)',
#  'Rami Levi Chain Stores Hashikma Marketing 2006 Ltd (TASE:RMLI)',
#  'Randstad Holding NV (ENXTAM:RAND)',
#  'Raubex Group Limited (JSE:RBX)',
#  'Realcan Pharmaceutical Co., Ltd. (SZSE:002589)',
#  'Red Robin Gourmet Burgers, Inc. (NasdaqGS:RRGB)',
#  'Redde plc (AIM:REDD)',
#  'Redington (India) Limited (BSE:532805)',
#  'Regis Corporation (NYSE:RGS)',
#  'Reliance Industries Limited (NSEI:RELIANCE)',
#  'Renrenle Commercial Group Co., Ltd. (SZSE:002336)',
#  'Rhön-Klinikum Aktiengesellschaft (DB:RHK)',
#  'Ricoh Company, Ltd. (TSE:7752)',
#  'Riso Kagaku Corporation (TSE:6413)',
#  'Rite Aid Corporation (NYSE:RAD)',
#  'Rohto Pharmaceutical Co., Ltd. (TSE:4527)',
#  'Rothschild & Co SCA (ENXTPA:ROTH)',
#  'Royal Mail plc (LSE:RMG)',
#  'Royal Unibrew A/S (CPSE:RBREW)',
#  'Ruby Tuesday, Inc. (NYSE:RT)',
#  'S&T Motiv Co., Ltd. (KOSE:A064960)',
#  'SATS Ltd. (SGX:S58)',
#  'SK Holdings Co., Ltd. (KOSE:A034730)',
#  'SM Prime Holdings, Inc. (PSE:SMPH)',
#  'SMA Solar Technology AG (XTRA:S92)',
#  'SMK Corporation (TSE:6798)',
#  'SPC Samlip Co., Ltd. (KOSE:A005610)',
#  'SPX Corporation (NYSE:SPXC)',
#  'STADA Arzneimittel Aktiengesellschaft (DB:SAZ)',
#  'SUEZ SA (ENXTPA:SEV)',
#  'Saint Marc Holdings Co., Ltd. (TSE:3395)',
#  'Salfacorp S.A. (SNSE:SALFACORP)',
#  'Samchully Co.,Ltd (KOSE:A004690)',
#  'Samho International Co., Ltd. (KOSE:A001880)',
#  'Sanix Incorporated (TSE:4651)',
#  'Sanki Engineering Co., Ltd. (TSE:1961)',
#  'Sankyu Inc. (TSE:9065)',
#  'Sanofi (ENXTPA:SAN)',
#  'Sanoma Oyj (HLSE:SAA1V)',
#  'Sanshin Electronics Co., Ltd. (TSE:8150)',
#  'Sapporo Holdings Limited (TSE:2501)',
#  'Saudi Pharmaceutical Industries & Medical Appliances Corporation (SASE:2070)',
#  'Saudi Telecom Company (SASE:7010)',
#  'Schibsted ASA (OB:SCHA)',
#  'Scorpio Tankers Inc. (NYSE:STNG)',
#  'Sears Canada Inc. (TSX:SCC)',
#  'Sears Holdings Corporation (NasdaqGS:SHLD)',
#  'Secure Energy Services Inc. (TSX:SES)',
#  'SemGroup Corporation (NYSE:SEMG)',
#  'Senko Co., Ltd. (TSE:9069)',
#  'Sensient Technologies Corporation (NYSE:SXT)',
#  'Seoul City Gas Co., Ltd. (KOSE:A017390)',
#  'Seven West Media Limited (ASX:SWM)',
#  'Shandong Bohui Paper Industry Co., Ltd. (SHSE:600966)',
#  'Shandong Humon Smelting Co., Ltd. (SZSE:002237)',
#  'Shandong Nanshan Aluminum Co., LTD (SHSE:600219)',
#  'Shanghai Aerospace Automobile Electromechanical Co., Ltd. (SHSE:600151)',
#  'Shanghai DaZhong Public Utilities(Group) Co.,Ltd (SHSE:600635)',
#  'Shanghai Fosun Pharmaceutical (Group) Co., Ltd. (SHSE:600196)',
#  'Shanghai Shenda Co., Ltd. (SHSE:600626)',
#  'Shaw Communications Inc. (TSX:SJR.B)',
#  'Shell Oman Marketing Company SAOG (MSM:SOMS)',
#  'Shenzhen Heungkong Holding Co., Ltd (SHSE:600162)',
#  'Shenzhen Kaifa Technology Co., Ltd. (SZSE:000021)',
#  'Shidax Corporation (JASDAQ:4837)',
#  'Shinhan Financial Group Co., Ltd. (KOSE:A055550)',
#  'Shinsegae Inc. (KOSE:A004170)',
#  'Shire plc (LSE:SHP)',
#  'Shree Cement Limited (BSE:500387)',
#  'Sichuan Languang Development Co., Ltd. (SHSE:600466)',
#  'Sieyuan Electric Co., Ltd. (SZSE:002028)',
#  'Silicon Works Co., Ltd. (KOSDAQ:A108320)',
#  'Singapore Exchange Limited (SGX:S68)',
#  'Singapore Post Limited (SGX:S08)',
#  'Singapore Telecommunications Limited (SGX:Z74)',
#  'Sino-Ocean Group Holding Limited (SEHK:3377)',
#  'Snam S.p.A. (BIT:SRG)',
#  'Société Anonyme des Bains de Mer et du Cercle des Étrangers à Monaco (ENXTPA:BAIN)',
#  'Sohu.com Inc. (NasdaqGS:SOHU)',
#  'Solar Applied Materials Technology Corp. (GTSM:1785)',
#  'SolarWorld Aktiengesellschaft (XTRA:SWVK)',
#  'Solasto Corporation (TSE:6197)',
#  'Solocal Group SA (ENXTPA:LOCAL)',
#  'Songa Offshore SE (OB:SONG)',
#  'Sonic Corp. (NasdaqGS:SONC)',
#  'Sony Corporation (TSE:6758)',
#  'Sotetsu Holdings, Inc. (TSE:9003)',
#  'Spark New Zealand Limited (NZSE:SPK)',
#  'Spire Inc. (NYSE:SR)',
#  'Staffline Group plc (AIM:STAF)',
#  'Stalprodukt S.A. (WSE:STP)',
#  'Stanley Electric Co. Ltd. (TSE:6923)',
#  'Start Today Co., Ltd. (TSE:3092)',
#  'State Street Corporation (NYSE:STT)',
#  'Stef SA (ENXTPA:STF)',
#  'Stein Mart, Inc. (NasdaqGS:SMRT)',
#  'Straumann Holding AG (SWX:STMN)',
#  'Suez Cement Company SAE (CASE:SUCE)',
#  'Sui Southern Gas Company Limited (KASE:SSGC)',
#  'Sun International Limited (JSE:SUI)',
#  'Sun Life Financial Inc. (TSX:SLF)',
#  'Sun Pharmaceutical Industries Limited (NSEI:SUNPHARMA)',
#  'Sungwoo Hitech Co., Ltd. (KOSDAQ:A015750)',
#  'Suning Universal Co.,Ltd (SZSE:000718)',
#  'Super Value Co., Ltd. (JASDAQ:3094)',
#  'Suzhou Dongshan Precision Manufacturing Co.,Ltd (SZSE:002384)',
#  'Suzhou Victory Precision Manufacture Co., Ltd. (SZSE:002426)',
#  'Suzuken Co., Ltd. (TSE:9987)',
#  'Swedish Orphan Biovitrum AB (OM:SOBI)',
#  'Swisscom AG (SWX:SCMN)',
#  'Sysco Corporation (NYSE:SYY)',
#  'Systemax Inc. (NYSE:SYX)',
#  'TBH Global Co., Ltd. (KOSE:A084870)',
#  'TEGNA Inc. (NYSE:TGNA)',
#  'TETRA Technologies, Inc. (NYSE:TTI)',
#  'TOA Corporation (TSE:1885)',
#  'TPV Technology Limited (SEHK:903)',
#  'TREVI - Finanziaria Industriale S.p.A. (BIT:TFI)',
#  'TYC Brother Industrial Co., Ltd. (TSEC:1522)',
#  'Taiwan Mobile Co., Ltd (TSEC:3045)',
#  'Takeda Pharmaceutical Company Limited (TSE:4502)',
#  'Talaat Mostafa Group Holding Company "TMG Holding" S.A.E. (CASE:TMGH)',
#  'Tamedia AG (SWX:TAMN)',
#  'Tata Global Beverages Limited (BSE:500800)',
#  'Tate & Lyle plc (LSE:TATE)',
#  'Teekay Tankers Ltd. (NYSE:TNK)',
#  'Tekken Corporation (TSE:1815)',
#  'Telefónica, S.A. (BME:TEF)',
#  'Telekom Slovenije d.d. (LJSE:TLSG)',
#  'Telephone and Data Systems, Inc. (NYSE:TDS)',
#  'Tencent Holdings Limited (SEHK:700)',
#  'Tenmaya Store Co., Ltd. (TSE:9846)',
#  'Tetra Tech, Inc. (NasdaqGS:TTEK)',
#  'The Advisory Board Company (NasdaqGS:ABCO)',
#  'The Bank of Nagoya, Ltd. (TSE:8522)',
#  'The Bank of New York Mellon Corporation (NYSE:BK)',
#  "The Brink's Company (NYSE:BCO)",
#  'The Coca-Cola Company (NYSE:KO)',
#  'The Indian Hotels Company Limited (BSE:500850)',
#  'The Kroger Co. (NYSE:KR)',
#  'The McClatchy Company (NYSE:MNI)',
#  'The New York Times Company (NYSE:NYT)',
#  'The Procter & Gamble Company (NYSE:PG)',
#  'Tianjin Chase Sun Pharmaceutical Co., Ltd. (SZSE:300026)',
#  'Tidewater Inc. (NYSE:TDW)',
#  'Titan Cement Company S.A. (ATSE:TITK)',
#  'Tobu Railway Co., Ltd. (TSE:9001)',
#  'Tobu Store Co., Ltd. (TSE:8274)',
#  'Toho Co., Ltd. (TSE:8142)',
#  'Toho Zinc Co., Ltd. (TSE:5707)',
#  'Tohto Suisan Co., Ltd. (TSE:8038)',
#  'Tokai Rika Co., Ltd. (TSE:6995)',
#  'Token Corporation (TSE:1766)',
#  'Tokyo Dome Corporation (TSE:9681)',
#  'Tokyo Electron Device Limited (TSE:2760)',
#  'TomTom N.V. (ENXTAM:TOM2)',
#  'Tongding Interconnection Information Co., Ltd. (SZSE:002491)',
#  'TransDigm Group Incorporated (NYSE:TDG)',
#  'Transocean Ltd. (NYSE:RIG)',
#  'Trend Micro Incorporated (TSE:4704)',
#  'Tsukada Global Holdings Inc. (TSE:2418)',
#  'Tsuzuki Denki Co., Ltd. (TSE:8157)',
#  'Tutor Perini Corporation (NYSE:TPC)',
#  'Técnicas Reunidas, S.A. (BME:TRE)',
#  'UDG Healthcare plc (LSE:UDG)',
#  'Uni-Select Inc. (TSX:UNS)',
#  'UniCredit S.p.A. (BIT:UCG)',
#  'Unione di Banche Italiane S.p.A. (BIT:UBI)',
#  'Unisys Corporation (NYSE:UIS)',
#  'Unit Corporation (NYSE:UNT)',
#  'Unitech Computer Co., Ltd. (TSEC:2414)',
#  'United Internet AG (DB:UTDI)',
#  'Unitika Ltd. (TSE:3103)',
#  'VCA Inc. (NasdaqGS:WOOF)',
#  'VSE Corporation (NasdaqGS:VSEC)',
#  'Vallourec SA (ENXTPA:VK)',
#  'Vantiv, Inc. (NYSE:VNTV)',
#  'Vectren Corporation (NYSE:VVC)',
#  'Venture Corporation Limited (SGX:V03)',
#  'Verizon Communications Inc. (NYSE:VZ)',
#  'Vetropack Holding AG (SWX:VET)',
#  'ViaSat, Inc. (NasdaqGS:VSAT)',
#  'Viad Corp (NYSE:VVI)',
#  'Viking Line ABP (HLSE:VIK1V)',
#  'Viña Concha y Toro S.A. (SNSE:CONCHATORO)',
#  'Vocento, S.A. (BME:VOC)',
#  'Vodafone Group Plc (LSE:VOD)',
#  'Vonage Holdings Corp. (NYSE:VG)',
#  'Vossloh AG (DB:VOS)',
#  'WASGAU Produktions & Handels AG (DB:MSH)',
#  'WH Smith PLC (LSE:SMWH)',
#  'WSP Global Inc. (TSX:WSP)',
#  'Wacom Co., Ltd. (TSE:6727)',
#  'Wah Lee Industrial Corp. (TSEC:3010)',
#  'Wakachiku Construction Co., Ltd. (TSE:1888)',
#  'Walter Investment Management Corp. (NYSE:WAC)',
#  'Weatherford International plc (NYSE:WFT)',
#  'Wesco Aircraft Holdings, Inc. (NYSE:WAIR)',
#  'Willbros Group, Inc. (NYSE:WG)',
#  'William Demant Holding A/S (CPSE:WDH)',
#  'Willis Towers Watson Public Limited Company (NasdaqGS:WLTW)',
#  'Windstream Holdings, Inc. (NasdaqGS:WIN)',
#  'Wirecard AG (XTRA:WDI)',
#  'Wolverine World Wide, Inc. (NYSE:WWW)',
#  'Woolworths Limited (ASX:WOW)',
#  'Woori Bank Co., Ltd. (KOSE:A000030)',
#  'Wright Medical Group N.V. (NasdaqGS:WMGI)',
#  'Wuxi Huaguang Boiler Co., ltd. (SHSE:600475)',
#  'X5 Retail Group N.V. (LSE:FIVE)',
#  'Xingfa Aluminium Holdings Limited (SEHK:98)',
#  'Xinhua Winshare Publishing and Media Co., Ltd. (SEHK:811)',
#  'YTL Corporation Berhad (KLSE:YTL)',
#  'YTL Power International Berhad (KLSE:YTLPOWR)',
#  'Yagi & Co., Ltd. (TSE:7460)',
#  'Yamaha Corporation (TSE:7951)',
#  'Yamatane Corporation (TSE:9305)',
#  'Yashima Denki Co., Ltd. (TSE:3153)',
#  'Yibin Tianyuan Group Co., Ltd. (SZSE:002386)',
#  'Yihua Lifestyle Technology Co., Ltd. (SHSE:600978)',
#  'Yingde Gases Group Company Limited (SEHK:2168)',
#  'Yokohama Maruuo Co., Ltd. (JASDAQ:8045)',
#  'Yonggao Co., Ltd. (SZSE:002641)',
#  'Yonghui Superstores Co., Ltd. (SHSE:601933)',
#  'Yoshinoya Holdings Co., Ltd. (TSE:9861)',
#  'Yuhan Corporation (KOSE:A000100)',
#  'ZTE Corp. (SZSE:000063)',
#  'Zhejiang CONBA Pharmaceutical Co.,Ltd. (SHSE:600572)',
#  'Zhejiang Huace Film & TV Co., Ltd. (SZSE:300133)',
#  'Zhejiang Materials Development Co., Ltd. (SZSE:000906)',
#  'Zhejiang Runtu Co., Ltd. (SZSE:002440)',
#  'Zhejiang Semir Garment Co., Ltd. (SZSE:002563)',
#  'Zhongbai Holdings Group Co., Ltd. (SZSE:000759)',
#  'Zhongshan Broad-Ocean Motor Co., Ltd. (SZSE:002249)',
#  'Zhongtian Urban Development Group Company Limited (SZSE:000540)',
#  'Zhongyeda Electric Co., Ltd. (SZSE:002441)',
#  'Zumtobel Group AG (WBAG:ZAG)',
#  'cocokara fine Inc. (TSE:3098)',
#  'eWork Group AB (publ) (OM:EWRK)',
#  'mobilezone holding ag (SWX:MOZN)',
#  'sebang Co., Ltd. (KOSE:A004360)'}

# %% [markdown]
# ## 1.3 Filter out Industries of our Interests

# %%
sector_list=list(set(df_ava["Total Revenue"]["AV Sector"]))
sector_list=list(np.sort(sector_list))
country_list=list(set(df_ava["Total Revenue"]["Country"]))
country_list=list(np.sort(country_list))

# %%
filter_idea_data = widgets.Accordion(
    children=[widgets.Dropdown(description="Select Sector",options=sector_list),
              widgets.Dropdown(description="Select Country",options=country_list),
             ])
filter_idea_data.set_title(0, 'Select Sector')
filter_idea_data.set_title(1, 'Select Country')
filter_idea_data

# %%
filter_button = widgets.Button(
    description='Load Filtered Data',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check'
)
display(filter_button)

def filter_button_click(click):
    global temp_db_filtered
    temp_db_filtered={}
    for table in list(temp_db.keys()):
        key=table
        temp_df = temp_db[table][temp_db[table]["Country"] == filter_idea_data.children[1].value]
#         temp_df = temp_df[temp_df["AV Sector"] == filter_idea_data.children[0].value]
        temp_db_filtered[key]=temp_df
    return(temp_db_filtered)
    print("Database Filtered by"+filter_idea_data.children[1].value)
    
filter_button.on_click(filter_button_click)

# %%
for idea in list(temp_db_filtered.keys()):
    print(temp_db_filtered[idea].head())
# Out:
#                                       Company Name Exchange:Ticker  \
# 6               Exxon Mobil Corporation (NYSE:XOM)        NYSE:XOM
# 37                  Chevron Corporation (NYSE:CVX)        NYSE:CVX
# 92       Archer-Daniels-Midland Company (NYSE:ADM)        NYSE:ADM
# 113                         Pfizer Inc. (NYSE:PFE)        NYSE:PFE
# 126  Hewlett Packard Enterprise Company (NYSE:HPE)        NYSE:HPE
#
#            Country         Region                 AV Industry  \
# 6    United States  North America  Resources/Process Material
# 37   United States  North America  Resources/Process Material
# 92   United States  North America  Resources/Process Material
# 113  United States  North America  Resources/Process Material
# 126  United States  North America                        TIME
#
#              AV Sector  FY2013  FY2014  FY2015
# 6            Oil & Gas  390247  364763  236810
# 37           Oil & Gas  211665  192308  122566
# 92                Food   89804   81201   67702
# 113             Pharma   51584   49605   48851
# 126  Tech HW Equipment   57371   55123   52107
#                                 Company Name Exchange:Ticker        Country  \
# 0           Wal-Mart Stores, Inc. (NYSE:WMT)        NYSE:WMT  United States
# 6         Exxon Mobil Corporation (NYSE:XOM)        NYSE:XOM  United States
# 7            McKesson Corporation (NYSE:MCK)        NYSE:MCK  United States
# 17  AmerisourceBergen Corporation (NYSE:ABC)        NYSE:ABC  United States
# 37            Chevron Corporation (NYSE:CVX)        NYSE:CVX  United States
#
#            Region                 AV Industry    AV Sector    FY2013  \
# 0   North America                    Services       Retail  0.059257
# 6   North America  Resources/Process Material    Oil & Gas  0.103270
# 7   North America                    Services  Health Care  0.018554
# 17  North America                    Services  Health Care  0.011244
# 37  North America  Resources/Process Material    Oil & Gas  0.128566
#
#       FY2014    FY2015
# 0   0.056419  0.056411
# 6   0.093436  0.054402
# 7   0.018327  0.017420
# 17  0.009914  0.009580
# 37  0.102409 -0.022796
# Empty DataFrame
# Columns: [Company Name, Exchange:Ticker, Country, Region, AV Industry, AV Sector, FY2013, FY2014, FY2015]
# Index: []
#                                 Company Name Exchange:Ticker        Country  \
# 27        General Electric Company (NYSE:GE)         NYSE:GE  United States
# 50     Microsoft Corporation (NasdaqGS:MSFT)   NasdaqGS:MSFT  United States
# 119             Sysco Corporation (NYSE:SYY)        NYSE:SYY  United States
# 251  The Goldman Sachs Group, Inc. (NYSE:GS)         NYSE:GS  United States
# 288    Tech Data Corporation (NasdaqGS:TECD)   NasdaqGS:TECD  United States
#
#             Region  AV Industry                   AV Sector    FY2013  \
# 27   North America  Engineering  Equipment Mech./Industrial  0.529396
# 50   North America         TIME      SW & Computer Services  0.260106
# 119  North America     Services                      Retail  0.822847
# 251  North America     Services          Financial Services  0.091124
# 288  North America         TIME      SW & Computer Services  0.948614
#
#        FY2014    FY2015
# 27   0.547689  0.690947
# 50   0.310182  0.353046
# 119  0.824127  0.824335
# 251  0.094995  0.100000
# 288  0.949208  0.949623
#                                     Company Name Exchange:Ticker  \
# 6             Exxon Mobil Corporation (NYSE:XOM)        NYSE:XOM
# 7                McKesson Corporation (NYSE:MCK)        NYSE:MCK
# 21              Amazon.com, Inc. (NasdaqGS:AMZN)   NasdaqGS:AMZN
# 28  Costco Wholesale Corporation (NasdaqGS:COST)   NasdaqGS:COST
# 37                Chevron Corporation (NYSE:CVX)        NYSE:CVX
#
#           Country         Region                 AV Industry      AV Sector  \
# 6   United States  North America  Resources/Process Material      Oil & Gas
# 7   United States  North America                    Services    Health Care
# 21  United States  North America                        TIME  Online Retail
# 28  United States  North America                    Services         Retail
# 37  United States  North America  Resources/Process Material      Oil & Gas
#
#       FY2013    FY2014    FY2015
# 6   0.036354  0.037479  0.052717
# 7   0.034282  0.039372  0.044129
# 21  0.172554  0.187104  0.190746
# 28  0.096571  0.097319  0.099054
# 37  0.030099  0.032068  0.051009

# %%
#Find the suckers that appear in all lists
sucker_bag=[]
for idea in list(temp_db_filtered.keys()):
    sucker_bag = sucker_bag + list(temp_db_filtered[idea]["Company Name"])
sucker_bag = list(np.sort(list(set(sucker_bag))))

# %%
sucker_bag
# Out:
# ['3D Systems Corporation (NYSE:DDD)',
#  'A. Schulman, Inc. (NasdaqGS:SHLM)',
#  'A.M. Castle & Co. (OTCPK:CASL)',
#  'AAR Corp. (NYSE:AIR)',
#  'ACCO Brands Corporation (NYSE:ACCO)',
#  'ACI Worldwide, Inc. (NasdaqGS:ACIW)',
#  'ADTRAN, Inc. (NasdaqGS:ADTN)',
#  'AMCON Distributing Company (AMEX:DIT)',
#  'ARRIS International plc (NasdaqGS:ARRS)',
#  'Actuant Corporation (NYSE:ATU)',
#  'Acxiom Corporation (NasdaqGS:ACXM)',
#  'Adams Resources & Energy, Inc. (AMEX:AE)',
#  'Adobe Systems Incorporated (NasdaqGS:ADBE)',
#  'Aegion Corporation (NasdaqGS:AEGN)',
#  'Affinion Group Holdings, Inc. (OTCPK:AFGR)',
#  'Aflac Incorporated (NYSE:AFL)',
#  'Agilent Technologies, Inc. (NYSE:A)',
#  'Albany International Corp. (NYSE:AIN)',
#  'Alere Inc. (NYSE:ALR)',
#  'Alliance Data Systems Corporation (NYSE:ADS)',
#  'Alliance Healthcare Services, Inc. (NasdaqGM:AIQ)',
#  'Alon USA Energy, Inc. (NYSE:ALJ)',
#  'Altra Industrial Motion Corp. (NasdaqGS:AIMC)',
#  'Amazon.com, Inc. (NasdaqGS:AMZN)',
#  'American Eagle Outfitters, Inc. (NYSE:AEO)',
#  'American Equity Investment Life Holding Company (NYSE:AEL)',
#  'AmerisourceBergen Corporation (NYSE:ABC)',
#  'Analogic Corporation (NasdaqGS:ALOG)',
#  'Applied Industrial Technologies, Inc. (NYSE:AIT)',
#  'AptarGroup, Inc. (NYSE:ATR)',
#  'Arch Coal, Inc. (NYSE:ARCH)',
#  'Archer-Daniels-Midland Company (NYSE:ADM)',
#  'Armstrong Flooring, Inc. (NYSE:AFI)',
#  'Arthur J. Gallagher & Co. (NYSE:AJG)',
#  'Ascena Retail Group, Inc. (NasdaqGS:ASNA)',
#  'Ascent Capital Group, Inc. (NasdaqGS:ASCM.A)',
#  'Ashland Global Holdings Inc. (NYSE:ASH)',
#  'Assurant, Inc. (NYSE:AIZ)',
#  'Atlas Air Worldwide Holdings, Inc. (NasdaqGS:AAWW)',
#  'AutoNation, Inc. (NYSE:AN)',
#  'Autodesk, Inc. (NasdaqGS:ADSK)',
#  'Avid Technology, Inc. (NasdaqGS:AVID)',
#  'Avis Budget Group, Inc. (NasdaqGS:CAR)',
#  'Avista Corporation (NYSE:AVA)',
#  'BWX Technologies, Inc. (NYSE:BWXT)',
#  'Ball Corporation (NYSE:BLL)',
#  'Barnes & Noble Education, Inc. (NYSE:BNED)',
#  'Barnes & Noble, Inc. (NYSE:BKS)',
#  'Baxter International Inc. (NYSE:BAX)',
#  'Becton, Dickinson and Company (NYSE:BDX)',
#  'Bed Bath & Beyond Inc. (NasdaqGS:BBBY)',
#  'Bel Fuse Inc. (NasdaqGS:BELF.B)',
#  'Bemis Company, Inc. (NYSE:BMS)',
#  'Benchmark Electronics, Inc. (NYSE:BHE)',
#  'Best Buy Co., Inc. (NYSE:BBY)',
#  'Biglari Holdings Inc. (NYSE:BH)',
#  'Bio-Techne Corporation (NasdaqGS:TECH)',
#  'Black Box Corporation (NasdaqGS:BBOX)',
#  'Blackhawk Network Holdings, Inc. (NasdaqGS:HAWK)',
#  'Blue Buffalo Pet Products, Inc. (NasdaqGS:BUFF)',
#  'Boart Longyear Limited (ASX:BLY)',
#  'Bob Evans Farms, Inc. (NasdaqGS:BOBE)',
#  "Bojangles', Inc. (NasdaqGS:BOJA)",
#  'Booz Allen Hamilton Holding Corporation (NYSE:BAH)',
#  'Bridgepoint Education, Inc. (NYSE:BPI)',
#  'Bristow Group Inc. (NYSE:BRS)',
#  'CA, Inc. (NasdaqGS:CA)',
#  'CACI International Inc (NYSE:CACI)',
#  'CBOE Holdings, Inc. (NasdaqGS:CBOE)',
#  'CBRE Group, Inc. (NYSE:CBG)',
#  'CF Industries Holdings, Inc. (NYSE:CF)',
#  'CONMED Corporation (NasdaqGS:CNMD)',
#  'CST Brands, Inc. (NYSE:CST)',
#  'Caesars Entertainment Corporation (NasdaqGS:CZR)',
#  'Calumet Specialty Products Partners, L.P. (NasdaqGS:CLMT)',
#  'Campbell Soup Company (NYSE:CPB)',
#  'CarMax Inc. (NYSE:KMX)',
#  'Cardtronics plc (NasdaqGS:CATM)',
#  'Carpenter Technology Corporation (NYSE:CRS)',
#  'Carrols Restaurant Group, Inc. (NasdaqGS:TAST)',
#  "Casey's General Stores, Inc. (NasdaqGS:CASY)",
#  'Caterpillar Inc. (NYSE:CAT)',
#  'Cedar Fair, L.P. (NYSE:FUN)',
#  'Celadon Group, Inc. (NYSE:CGI)',
#  'Centene Corporation (NYSE:CNC)',
#  'CenturyLink, Inc. (NYSE:CTL)',
#  'Charles River Laboratories International, Inc. (NYSE:CRL)',
#  'Chart Industries, Inc. (NasdaqGS:GTLS)',
#  'Chemtura Corporation (NYSE:CHMT)',
#  'Chesapeake Energy Corporation (NYSE:CHK)',
#  'Chevron Corporation (NYSE:CVX)',
#  'Choice Hotels International, Inc. (NYSE:CHH)',
#  'Ciber, Inc. (NYSE:CBR)',
#  'Cincinnati Bell Inc. (NYSE:CBB)',
#  'Cliffs Natural Resources Inc. (NYSE:CLF)',
#  'Cloud Peak Energy Inc. (NYSE:CLD)',
#  'ClubCorp Holdings, Inc. (NYSE:MYCC)',
#  'Coach, Inc. (NYSE:COH)',
#  'Cognizant Technology Solutions Corporation (NasdaqGS:CTSH)',
#  'Columbus McKinnon Corporation (NasdaqGS:CMCO)',
#  'Commerce Bancshares, Inc. (NasdaqGS:CBSH)',
#  'Community Health Systems, Inc. (NYSE:CYH)',
#  'Computer Sciences Corporation (NYSE:CSC)',
#  'Concho Resources Inc. (NYSE:CXO)',
#  'ConocoPhillips (NYSE:COP)',
#  'Cooper Tire & Rubber Company (NYSE:CTB)',
#  'Costco Wholesale Corporation (NasdaqGS:COST)',
#  'Covanta Holding Corporation (NYSE:CVA)',
#  'Cracker Barrel Old Country Store, Inc. (NasdaqGS:CBRL)',
#  'Crawford & Company (NYSE:CRD.B)',
#  'Cray Inc. (NasdaqGS:CRAY)',
#  'Crocs, Inc. (NasdaqGS:CROX)',
#  'CrossAmerica Partners LP (NYSE:CAPL)',
#  'Cubic Corporation (NYSE:CUB)',
#  'Cumulus Media Inc. (NasdaqCM:CMLS)',
#  'DISH Network Corporation (NasdaqGS:DISH)',
#  'DSW Inc. (NYSE:DSW)',
#  'DTE Energy Company (NYSE:DTE)',
#  'DXP Enterprises, Inc. (NasdaqGS:DXPE)',
#  'DaVita Inc. (NYSE:DVA)',
#  'Dana Incorporated (NYSE:DAN)',
#  'Darling Ingredients Inc. (NYSE:DAR)',
#  'DeVry Education Group Inc. (NYSE:DV)',
#  'Delek US Holdings, Inc. (NYSE:DK)',
#  'Dell Technologies Inc. (NYSE:DVMT)',
#  'Devon Energy Corporation (NYSE:DVN)',
#  'Discovery Communications, Inc. (NasdaqGS:DISC.A)',
#  'Dolby Laboratories, Inc. (NYSE:DLB)',
#  'Dollar Tree, Inc. (NasdaqGS:DLTR)',
#  'Domtar Corporation (NYSE:UFS)',
#  'Donaldson Company, Inc. (NYSE:DCI)',
#  'Ducommun Incorporated (NYSE:DCO)',
#  'EMCOR Group, Inc. (NYSE:EME)',
#  'EPAM Systems, Inc. (NYSE:EPAM)',
#  'EZCORP, Inc. (NasdaqGS:EZPW)',
#  'Eastman Kodak Company (NYSE:KODK)',
#  'Echo Global Logistics, Inc. (NasdaqGS:ECHO)',
#  'Edgewell Personal Care Company (NYSE:EPC)',
#  'EnPro Industries, Inc. (NYSE:NPO)',
#  'EnerSys (NYSE:ENS)',
#  'Energen Corporation (NYSE:EGN)',
#  'Energizer Holdings, Inc. (NYSE:ENR)',
#  'Enova International, Inc. (NYSE:ENVA)',
#  'Entegris, Inc. (NasdaqGS:ENTG)',
#  'Everi Holdings Inc. (NYSE:EVRI)',
#  'Expedia, Inc. (NasdaqGS:EXPE)',
#  'Express, Inc. (NYSE:EXPR)',
#  'Extreme Networks, Inc. (NasdaqGS:EXTR)',
#  'Exxon Mobil Corporation (NYSE:XOM)',
#  'FLIR Systems, Inc. (NasdaqGS:FLIR)',
#  'FTI Consulting, Inc. (NYSE:FCN)',
#  'FactSet Research Systems Inc. (NYSE:FDS)',
#  'Fair Isaac Corporation (NYSE:FICO)',
#  'Fairmount Santrol Holdings Inc. (NYSE:FMSA)',
#  'Fairpoint Communications, Inc. (NasdaqCM:FRP)',
#  'Ferro Corporation (NYSE:FOE)',
#  'First Republic Bank (NYSE:FRC)',
#  'FirstCash, Inc. (NYSE:FCFS)',
#  'Fluor Corporation (NYSE:FLR)',
#  'Foresight Energy LP (NYSE:FELP)',
#  'Fortinet, Inc. (NasdaqGS:FTNT)',
#  'Forum Energy Technologies, Inc. (NYSE:FET)',
#  'Forward Air Corporation (NasdaqGS:FWRD)',
#  'Fossil Group, Inc. (NasdaqGS:FOSL)',
#  'Franklin Electric Co., Inc. (NasdaqGS:FELE)',
#  'Freeport-McMoRan Inc. (NYSE:FCX)',
#  'Frontier Communications Corporation (NasdaqGS:FTR)',
#  'Fulton Financial Corporation (NasdaqGS:FULT)',
#  'G-III Apparel Group, Ltd. (NasdaqGS:GIII)',
#  'GNC Holdings, Inc. (NYSE:GNC)',
#  'GTT Communications, Inc. (NYSE:GTT)',
#  'GameStop Corp. (NYSE:GME)',
#  'Gannett Co., Inc. (NYSE:GCI)',
#  'Gartner, Inc. (NYSE:IT)',
#  'General Electric Company (NYSE:GE)',
#  'General Mills, Inc. (NYSE:GIS)',
#  'Genesco Inc. (NYSE:GCO)',
#  'Genesis Energy, L.P. (NYSE:GEL)',
#  'Global Partners LP (NYSE:GLP)',
#  'Globus Medical, Inc. (NYSE:GMED)',
#  'Gordmans Stores, Inc. (NasdaqGS:GMAN)',
#  'Graco Inc. (NYSE:GGG)',
#  'Green Dot Corporation (NYSE:GDOT)',
#  'Guess?, Inc. (NYSE:GES)',
#  'HP Inc. (NYSE:HPQ)',
#  'HRG Group, Inc. (NYSE:HRG)',
#  'Halyard Health, Inc. (NYSE:HYH)',
#  'Hancock Holding Company (NasdaqGS:HBHC)',
#  'Hanesbrands Inc. (NYSE:HBI)',
#  'Harsco Corporation (NYSE:HSC)',
#  'Hasbro, Inc. (NasdaqGS:HAS)',
#  'Heartland Express, Inc. (NasdaqGS:HTLD)',
#  'Hess Corporation (NYSE:HES)',
#  'Hewlett Packard Enterprise Company (NYSE:HPE)',
#  'Hilltop Holdings Inc. (NYSE:HTH)',
#  'Houghton Mifflin Harcourt Company (NasdaqGS:HMHC)',
#  'Humana Inc. (NYSE:HUM)',
#  'ICF International, Inc. (NasdaqGS:ICFI)',
#  'ILG, Inc. (NasdaqGS:ILG)',
#  'INTL FCStone Inc. (NasdaqGS:INTL)',
#  'Indivior PLC (LSE:INDV)',
#  'Ingevity Corporation (NYSE:NGVT)',
#  'Ingredion Incorporated (NYSE:INGR)',
#  'Innophos Holdings, Inc. (NasdaqGS:IPHS)',
#  'Innospec Inc. (NasdaqGS:IOSP)',
#  'Insperity, Inc. (NYSE:NSP)',
#  'Inter Parfums, Inc. (NasdaqGS:IPAR)',
#  'International Business Machines Corporation (NYSE:IBM)',
#  'International Speedway Corporation (NasdaqGS:ISCA)',
#  'Intuitive Surgical, Inc. (NasdaqGS:ISRG)',
#  'Invacare Corporation (NYSE:IVC)',
#  'Itron, Inc. (NasdaqGS:ITRI)',
#  'J.B. Hunt Transport Services, Inc. (NasdaqGS:JBHT)',
#  'John Bean Technologies Corporation (NYSE:JBT)',
#  'John Wiley & Sons, Inc. (NYSE:JW.A)',
#  'Jones Lang LaSalle Incorporated (NYSE:JLL)',
#  'Joy Global Inc. (NYSE:JOY)',
#  'KBR, Inc. (NYSE:KBR)',
#  'KEMET Corporation (NYSE:KEM)',
#  'Kennametal Inc. (NYSE:KMT)',
#  'Kennedy-Wilson Holdings, Inc. (NYSE:KW)',
#  'Kimball International, Inc. (NasdaqGS:KBAL)',
#  "Kohl's Corporation (NYSE:KSS)",
#  'Korn/Ferry International (NYSE:KFY)',
#  'Kraton Corporation (NYSE:KRA)',
#  'Kratos Defense & Security Solutions, Inc. (NasdaqGS:KTOS)',
#  'L.B. Foster Company (NasdaqGS:FSTR)',
#  'L3 Technologies, Inc. (NYSE:LLL)',
#  'Laboratory Corporation of America Holdings (NYSE:LH)',
#  'Lancaster Colony Corporation (NasdaqGS:LANC)',
#  'Landec Corporation (NasdaqGS:LNDC)',
#  "Lands' End, Inc. (NasdaqCM:LE)",
#  'Laredo Petroleum, Inc. (NYSE:LPI)',
#  'Layne Christensen Company (NasdaqGS:LAYN)',
#  'Lee Enterprises, Incorporated (NYSE:LEE)',
#  'Lennar Corporation (NYSE:LEN)',
#  'Libbey Inc. (AMEX:LBY)',
#  'Liberty TripAdvisor Holdings, Inc. (NasdaqGS:LTRP.A)',
#  'LifeLock, Inc. (NYSE:LOCK)',
#  'LifePoint Health, Inc. (NasdaqGS:LPNT)',
#  'Lincoln Electric Holdings, Inc. (NasdaqGS:LECO)',
#  'Lincoln National Corporation (NYSE:LNC)',
#  'Lithia Motors, Inc. (NYSE:LAD)',
#  'Lumber Liquidators Holdings, Inc. (NYSE:LL)',
#  'MACOM Technology Solutions Holdings, Inc. (NasdaqGS:MTSI)',
#  'MB Financial, Inc. (NasdaqGS:MBFI)',
#  'MEDNAX, Inc. (NYSE:MD)',
#  'MRC Global Inc. (NYSE:MRC)',
#  'MSC Industrial Direct Co., Inc. (NYSE:MSM)',
#  'MTS Systems Corporation (NasdaqGS:MTSC)',
#  "Macy's, Inc. (NYSE:M)",
#  'Magellan Health, Inc. (NasdaqGS:MGLN)',
#  'ManTech International Corporation (NasdaqGS:MANT)',
#  'Marathon Oil Corporation (NYSE:MRO)',
#  'Marten Transport, Ltd. (NasdaqGS:MRTN)',
#  'Martin Midstream Partners L.P. (NasdaqGS:MMLP)',
#  'MasTec, Inc. (NYSE:MTZ)',
#  'Materion Corporation (NYSE:MTRN)',
#  'Matson, Inc. (NYSE:MATX)',
#  'Mattel, Inc. (NasdaqGS:MAT)',
#  'Matthews International Corporation (NasdaqGS:MATW)',
#  "McDonald's Corporation (NYSE:MCD)",
#  'McKesson Corporation (NYSE:MCK)',
#  'Merck & Co., Inc. (NYSE:MRK)',
#  'Meritor, Inc. (NYSE:MTOR)',
#  'Metaldyne Performance Group Inc. (NYSE:MPG)',
#  'Microsoft Corporation (NasdaqGS:MSFT)',
#  'Mistras Group, Inc. (NYSE:MG)',
#  'Mobile Mini, Inc. (NasdaqGS:MINI)',
#  'Modine Manufacturing Company (NYSE:MOD)',
#  'Molson Coors Brewing Company (NYSE:TAP)',
#  'MoneyGram International, Inc. (NasdaqGS:MGI)',
#  'Moog Inc. (NYSE:MOG.A)',
#  'Motorola Solutions, Inc. (NYSE:MSI)',
#  'Murphy Oil Corporation (NYSE:MUR)',
#  'Murphy USA Inc. (NYSE:MUSA)',
#  'Myers Industries, Inc. (NYSE:MYE)',
#  'NACCO Industries, Inc. (NYSE:NC)',
#  'NETGEAR, Inc. (NasdaqGS:NTGR)',
#  'NII Holdings, Inc. (NasdaqGS:NIHD)',
#  'National HealthCare Corporation (AMEX:NHC)',
#  'National Oilwell Varco, Inc. (NYSE:NOV)',
#  'NeuStar, Inc. (NYSE:NSR)',
#  'New Media Investment Group Inc. (NYSE:NEWM)',
#  'Nexstar Broadcasting Group, Inc. (NasdaqGS:NXST)',
#  'NiSource Inc. (NYSE:NI)',
#  'Noble Energy, Inc. (NYSE:NBL)',
#  'Nordson Corporation (NasdaqGS:NDSN)',
#  'Nordstrom, Inc. (NYSE:JWN)',
#  'Northrop Grumman Corporation (NYSE:NOC)',
#  'NuStar Energy L.P. (NYSE:NS)',
#  'Nucor Corporation (NYSE:NUE)',
#  'OGE Energy Corp. (NYSE:OGE)',
#  'OMNOVA Solutions Inc. (NYSE:OMN)',
#  'Oasis Petroleum Inc. (NYSE:OAS)',
#  'Occidental Petroleum Corporation (NYSE:OXY)',
#  'Ocwen Financial Corporation (NYSE:OCN)',
#  'Oil States International, Inc. (NYSE:OIS)',
#  'Olin Corporation (NYSE:OLN)',
#  'Olympic Steel, Inc. (NasdaqGS:ZEUS)',
#  'Omnicell, Inc. (NasdaqGS:OMCL)',
#  'Omnicom Group Inc. (NYSE:OMC)',
#  'Oshkosh Corporation (NYSE:OSK)',
#  'Outfront Media Inc. (NYSE:OUT)',
#  'Owens-Illinois, Inc. (NYSE:OI)',
#  'Oxford Industries, Inc. (NYSE:OXM)',
#  'PBF Energy Inc. (NYSE:PBF)',
#  'PHH Corporation (NYSE:PHH)',
#  'PVH Corp. (NYSE:PVH)',
#  'Pacific Sunwear of California, LLC (DB:PSU)',
#  'Palo Alto Networks, Inc. (NYSE:PANW)',
#  'Panera Bread Company (NasdaqGS:PNRA)',
#  'Park-Ohio Holdings Corp. (NasdaqGS:PKOH)',
#  'Patterson Companies, Inc. (NasdaqGS:PDCO)',
#  'Patterson-UTI Energy, Inc. (NasdaqGS:PTEN)',
#  'Pepsico, Inc. (NYSE:PEP)',
#  'Perry Ellis International, Inc. (NasdaqGS:PERY)',
#  'Pfizer Inc. (NYSE:PFE)',
#  'Philip Morris International Inc. (NYSE:PM)',
#  'Pioneer Natural Resources Company (NYSE:PXD)',
#  'Pitney Bowes Inc. (NYSE:PBI)',
#  'Plantronics, Inc. (NYSE:PLT)',
#  'Ply Gem Holdings, Inc (NYSE:PGEM)',
#  'Post Holdings, Inc. (NYSE:POST)',
#  'Premier, Inc. (NasdaqGS:PINC)',
#  'Prestige Brands Holdings, Inc. (NYSE:PBH)',
#  'ProAssurance Corporation (NYSE:PRA)',
#  'Quad/Graphics, Inc. (NYSE:QUAD)',
#  'R.R. Donnelley & Sons Company (NYSE:RRD)',
#  'R1 RCM Inc. (OTCPK:ACHI)',
#  'RPC, Inc. (NYSE:RES)',
#  'Radiant Logistics, Inc. (AMEX:RLGT)',
#  'Range Resources Corporation (NYSE:RRC)',
#  'Rayonier Advanced Materials Inc. (NYSE:RYAM)',
#  'Raytheon Company (NYSE:RTN)',
#  'Real Industry, Inc. (NasdaqGS:RELY)',
#  'Red Hat, Inc. (NYSE:RHT)',
#  'Regeneron Pharmaceuticals, Inc. (NasdaqGS:REGN)',
#  'Regions Financial Corporation (NYSE:RF)',
#  'Regis Corporation (NYSE:RGS)',
#  'Rent-A-Center, Inc. (NasdaqGS:RCII)',
#  'Rexnord Corporation (NYSE:RXN)',
#  'Roadrunner Transportation Systems, Inc. (NYSE:RRTS)',
#  'Ruby Tuesday, Inc. (NYSE:RT)',
#  'SM Energy Company (NYSE:SM)',
#  'SP Plus Corporation (NasdaqGS:SP)',
#  'SPX Corporation (NYSE:SPXC)',
#  'SPX FLOW, Inc. (NYSE:FLOW)',
#  'Sanderson Farms, Inc. (NasdaqGS:SAFM)',
#  'ScanSource, Inc. (NasdaqGS:SCSC)',
#  'Schnitzer Steel Industries, Inc. (NasdaqGS:SCHN)',
#  'Scripps Networks Interactive, Inc. (NasdaqGS:SNI)',
#  'Sears Holdings Corporation (NasdaqGS:SHLD)',
#  'Sears Hometown and Outlet Stores, Inc. (NasdaqCM:SHOS)',
#  'Select Comfort Corporation (NasdaqGS:SCSS)',
#  'Select Medical Holdings Corporation (NYSE:SEM)',
#  'Shiloh Industries, Inc. (NasdaqGS:SHLO)',
#  'Shoe Carnival, Inc. (NasdaqGS:SCVL)',
#  'Shutterfly, Inc. (NasdaqGS:SFLY)',
#  'Silgan Holdings Inc. (NasdaqGS:SLGN)',
#  'Silicon Laboratories Inc. (NasdaqGS:SLAB)',
#  'Sims Metal Management Limited (ASX:SGM)',
#  'Sinclair Broadcast Group, Inc. (NasdaqGS:SBGI)',
#  'SkyWest, Inc. (NasdaqGS:SKYW)',
#  'Sonic Automotive, Inc. (NYSE:SAH)',
#  'Sonic Corp. (NasdaqGS:SONC)',
#  "Sotheby's (NYSE:BID)",
#  'Southwestern Energy Company (NYSE:SWN)',
#  'SpartanNash Company (NasdaqGS:SPTN)',
#  'Splunk Inc. (NasdaqGS:SPLK)',
#  'Staples, Inc. (NasdaqGS:SPLS)',
#  'Steel Dynamics, Inc. (NasdaqGS:STLD)',
#  'Stein Mart, Inc. (NasdaqGS:SMRT)',
#  'Stratasys Ltd. (NasdaqGS:SSYS)',
#  'SunCoke Energy, Inc. (NYSE:SXC)',
#  'Sunoco LP (NYSE:SUN)',
#  'Sunoco Logistics Partners L.P. (NYSE:SXL)',
#  'Superior Industries International, Inc. (NYSE:SUP)',
#  'Surgical Care Affiliates, Inc. (NasdaqGS:SCAI)',
#  'Swift Transportation Company (NYSE:SWFT)',
#  'Symantec Corporation (NasdaqGS:SYMC)',
#  'Synchrony Financial (NYSE:SYF)',
#  'Sysco Corporation (NYSE:SYY)',
#  'TEGNA Inc. (NYSE:TGNA)',
#  'Tableau Software, Inc. (NYSE:DATA)',
#  'Tailored Brands, Inc. (NYSE:TLRD)',
#  'Tallgrass Energy Partners, LP (NYSE:TEP)',
#  'Tech Data Corporation (NasdaqGS:TECD)',
#  'TeleTech Holdings, Inc. (NasdaqGS:TTEC)',
#  'Teradata Corporation (NYSE:TDC)',
#  'Tesoro Corporation (NYSE:TSO)',
#  'Texas Capital Bancshares, Inc. (NasdaqGS:TCBI)',
#  'Texas Roadhouse, Inc. (NasdaqGS:TXRH)',
#  'The Andersons, Inc. (NasdaqGS:ANDE)',
#  'The Cato Corporation (NYSE:CATO)',
#  "The Chefs' Warehouse, Inc. (NasdaqGS:CHEF)",
#  'The Chemours Company (NYSE:CC)',
#  "The Children's Place, Inc. (NasdaqGS:PLCE)",
#  'The Coca-Cola Company (NYSE:KO)',
#  'The Dow Chemical Company (NYSE:DOW)',
#  'The Ensign Group, Inc. (NasdaqGS:ENSG)',
#  'The Finish Line, Inc. (NasdaqGS:FINL)',
#  'The Goldman Sachs Group, Inc. (NYSE:GS)',
#  'The Goodyear Tire & Rubber Company (NasdaqGS:GT)',
#  'The Hain Celestial Group, Inc. (NasdaqGS:HAIN)',
#  'The Hartford Financial Services Group, Inc. (NYSE:HIG)',
#  'The J. M. Smucker Company (NYSE:SJM)',
#  'The McClatchy Company (NYSE:MNI)',
#  'The Priceline Group Inc. (NasdaqGS:PCLN)',
#  'The Timken Company (NYSE:TKR)',
#  'The Travelers Companies, Inc. (NYSE:TRV)',
#  'The Ultimate Software Group, Inc. (NasdaqGS:ULTI)',
#  "The Wendy's Company (NasdaqGS:WEN)",
#  'The Western Union Company (NYSE:WU)',
#  'The Williams Companies, Inc. (NYSE:WMB)',
#  'Thomson Reuters Corporation (TSX:TRI)',
#  'TiVo Corporation (NasdaqGS:TIVO)',
#  "Tilly's, Inc. (NYSE:TLYS)",
#  'Time Inc. (NYSE:TIME)',
#  'TimkenSteel Corporation (NYSE:TMST)',
#  'Titan International, Inc. (NYSE:TWI)',
#  'Titan Machinery Inc. (NasdaqGS:TITN)',
#  'Total System Services, Inc. (NYSE:TSS)',
#  'Tower International, Inc. (NYSE:TOWR)',
#  'TransUnion (NYSE:TRU)',
#  'TravelCenters of America LLC (NasdaqGS:TA)',
#  'TriNet Group, Inc. (NYSE:TNET)',
#  'Trimble Inc. (NasdaqGS:TRMB)',
#  'Trinseo S.A. (NYSE:TSE)',
#  'TripAdvisor, Inc. (NasdaqGS:TRIP)',
#  'Triton International Limited (NYSE:TRTN)',
#  'TrueBlue, Inc. (NYSE:TBI)',
#  'Trustmark Corporation (NasdaqGS:TRMK)',
#  'Tyson Foods, Inc. (NYSE:TSN)',
#  'U.S. Silica Holdings, Inc. (NYSE:SLCA)',
#  'Unifi, Inc. (NYSE:UFI)',
#  'Unisys Corporation (NYSE:UIS)',
#  'United Natural Foods, Inc. (NasdaqGS:UNFI)',
#  'Universal American Corp. (NYSE:UAM)',
#  'VOXX International Corporation (NasdaqGS:VOXX)',
#  'Valero Energy Corporation (NYSE:VLO)',
#  'Valley National Bancorp (NYSE:VLY)',
#  'Varian Medical Systems, Inc. (NYSE:VAR)',
#  'Vectrus, Inc. (NYSE:VEC)',
#  'Vera Bradley, Inc. (NasdaqGS:VRA)',
#  'Verisk Analytics, Inc. (NasdaqGS:VRSK)',
#  'Viacom, Inc. (NasdaqGS:VIAB)',
#  'Viavi Solutions Inc. (NasdaqGS:VIAV)',
#  'Vitamin Shoppe, Inc. (NYSE:VSI)',
#  'Volt Information Sciences, Inc. (AMEX:VISI)',
#  'WEX Inc. (NYSE:WEX)',
#  'Wal-Mart Stores, Inc. (NYSE:WMT)',
#  'Walter Investment Management Corp. (NYSE:WAC)',
#  'Weight Watchers International, Inc. (NYSE:WTW)',
#  'Werner Enterprises, Inc. (NasdaqGS:WERN)',
#  'Wesco Aircraft Holdings, Inc. (NYSE:WAIR)',
#  'West Corporation (NasdaqGS:WSTC)',
#  'West Marine, Inc. (NasdaqGS:WMAR)',
#  'Western Digital Corporation (NasdaqGS:WDC)',
#  'Western Refining, Inc. (NYSE:WNR)',
#  'Westlake Chemical Partners LP (NYSE:WLKP)',
#  'Westmoreland Coal Company (NasdaqGM:WLB)',
#  'Whirlpool Corporation (NYSE:WHR)',
#  'Whiting Petroleum Corporation (NYSE:WLL)',
#  'Windstream Holdings, Inc. (NasdaqGS:WIN)',
#  'World Fuel Services Corporation (NYSE:INT)',
#  'Xcel Energy Inc. (NYSE:XEL)',
#  'Xerox Corporation (NYSE:XRX)',
#  'Xylem Inc. (NYSE:XYL)',
#  'Yahoo! Inc. (NasdaqGS:YHOO)',
#  'Yum! Brands, Inc. (NYSE:YUM)',
#  'Zebra Technologies Corporation (NasdaqGS:ZBRA)',
#  'athenahealth, Inc. (NasdaqGS:ATHN)',
#  'iHeartMedia, Inc. (OTCPK:IHRT)',
#  'j2 Global, Inc. (NasdaqGS:JCOM)',
#  'salesforce.com, inc. (NYSE:CRM)',
#  'tronc, Inc. (NasdaqGM:TRNC)']
